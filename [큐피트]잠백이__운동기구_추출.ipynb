# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 2.1 mecab 설치

# %%
# Install the required packages using Colab-specific commands
# !apt-get update
# !apt-get install -y g++ openjdk-8-jdk
# !pip install JPype1
# !pip install konlpy
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [634 kB]
# Get:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease [18.1 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,326 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,305 kB]
# ...

# %%
# %env JAVA_HOME "/usr/lib/jvm/java-8-openjdk-amd64"
# Out:
# env: JAVA_HOME="/usr/lib/jvm/java-8-openjdk-amd64"

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 138 (delta 26), reused 22 (delta 8), pack-reused 91
# Receiving objects: 100% (138/138), 1.72 MiB | 9.29 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
cd Mecab-ko-for-Google-Colab
# Out:
# /content/Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab_light_220429.sh # 오래 걸림ㅠㅠ
# Out:
# Installing konlpy.....
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2023-12-17 01:54:30--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22cd:e0db
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# ### 2.2 사용자 사전 생성

# %%
# 디렉토리 변경
# %cd /content/mecab-ko-dic-2.1.1-20180720
# Out:
# /content/mecab-ko-dic-2.1.1-20180720

# %%
# 파일 목록
# %ls user-dic
# Out:
# nnp.csv  person.csv  place.csv  README.md  user-nnp.csv

# %%
# 연결 확인
# !cat user-dic/nnp.csv
# Out:
# 대우,,,,NNP,*,F,대우,*,*,*,*,*
# 구글,,,,NNP,*,T,구글,*,*,*,*,*

# %%
# 파일 목록 표시
# %ls
# Out:
# aclocal.m4       configure.ac~  INSTALL      model.def          pos-id.def       user-user-nnp.csv
# AUTHORS          COPYING        install-sh*  NEWS               Preanalysis.csv  VA.csv
# autogen.sh*      dicrc          J.csv        NNBC.csv           README           VCN.csv
# autom4te.cache/  EC.csv         left-id.def  NNB.csv            rewrite.def      VCP.csv
# ChangeLog        EF.csv         MAG.csv      NNG.csv            right-id.def     VV.csv
# char.bin         EP.csv         MAJ.csv      NNP.csv            Symbol.csv       VX.csv
# char.def         ETM.csv        Makefile     NorthKorea.csv     sys.dic          Wikipedia.csv
# clean*           ETN.csv        Makefile.am  NP.csv             tools/           XPN.csv
# CoinedWord.csv   feature.def    Makefile.in  NR.csv             unk.def          XR.csv
# config.log       Foreign.csv    matrix.bin   Person-actor.csv   unk.dic          XSA.csv
# ...

# %%
# !pip install jamo

# %%
from jamo import h2j, j2hcj

# 사용자 정의 사전에 단어 추가 시, 마지막 글자의 종성 유무 규명 함수
def get_jongsung_TF(sample_text):
    sample_text_list = list(sample_text)
    last_word = sample_text_list[-1]
    last_word_jamo_list = list(j2hcj(h2j(last_word)))
    last_jamo = last_word_jamo_list[-1]

    jongsung_TF = "T"

    if last_jamo in ['ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ', 'ㅘ', 'ㅚ', 'ㅙ', 'ㅝ', 'ㅞ', 'ㅢ', 'ㅐ,ㅔ', 'ㅟ', 'ㅖ', 'ㅒ']:
        jongsung_TF = "F"

    return jongsung_TF

# %%
# get_jongsung_TF  작동 확인
print(get_jongsung_TF('감자'))
print(get_jongsung_TF('귤'))
# Out:
# F
# T

# %%
import pandas as pd

# %%
# 사용자단어 사전 'user-nnp.csv' 파일 생성 함수
# 단어 목록에 포함된 단어의 끝글자 종성유무 판단 후 file_data 리스트에 추가
# file_data 리스트의 각 줄을 읽어 user-nnp.csv 파일에 입력

def make_user_dic_csv(morpheme_type, word_list, user_dic_file_name):
  file_data = []

  for word, score in word_list:
    jongsung_TF = get_jongsung_TF(word)

    line = f"{word},,,{score},{morpheme_type},*,{jongsung_TF},{word},*,*,*,*,*\n"

    file_data.append(line)

  with open("./user-dic/user-nnp.csv", 'w', encoding='utf-8') as f:
    for line in file_data:
      f.write(line)

# %%
word_list = [('파나타', 1),('파나타머신', 0),('헬스장', 0), ('샤워장', 0), ('케틀벨', 0), ('타겟팅', 0),
             ('렉스코', 0), ('천국의 계단', 0), ('퓨어 스트랭스', 0), ('벤치', 0), ('너틸러스',0), ('너틸 러스',0), ('노틸러스',0), ('Nautilus',0),
             ('사이벡', 0), ('파워렉', 0), ('랫풀다운', 0), ('덤밸', 0), ('울트라 스트랭스', 0), ('울트라 스트랭쓰', 0),
             ('찌린내', 0), ('스쿼트랙', 0), ('프리웨이트', 0), ('힙스트러스트', 0), ('해머머신', 0), ('랖프', 0), ('해머 스트렝스', 0),
             ('해머스트렝스',0), ('해머 스트랭스',0), ('해머스트랭스',0), ('해머',1), ('Hammer Strength',0), ('셀렉트',0), ('MTS',0),
             ('사이벡스', 0),('싸이벡스', 0), ('Cybex',0), ('싸벡',0), ('짐80', 0), ('Gym80', 0), ('gym80', 0), ('GYM80', 0),
             ('테크노짐', 0), ('테크노',1), ('Technogym',0), ('프리모션',0), ('라이프피트니스', 0), ('라이프',1),('라이프 휘트니스', 0),
             ('아스널스트렝스',0), ('아스널스트랭스',0), ('아스널 스트랭스',0), ('아스널 스트렝스',0), ('아스날스트렝스',0), ('아스날스트랭스',0), ('아스날 스트랭스',0), ('아스날 스트렝스',0), ('아스널',1), ('아스날',1),
             ('디렉스',0), ('DRAX',0), ('아틀란티스',0), ('이카리안',0), ('프라임',0), ('Prime',0),('플렉스휘트니스',0), ('플렉스',1),
              ('울트라스트랭스',0), ('울트라스트렝스',0), ('호이스트',0), ('Hoist',0),('부티빌더',0), ('BootyBuilder',0), ('로저스애슬래틱',0), ('로저스',1), ('로저스 애슬래틱',0), ('로저',1),('로저스애슬래틱',0),
             ('포커스',0), ('Focus',0), ('다이나바디',0), ('Dynabody',0), ('소리넥스',0), ('Sorinex',0),('프로막시나',0), ('ProMaxima',0),
              ('파워리프트',0), ('PowerLift',0), ('짐박스',0), ('Gymboxx',0),('뉴테크',0), ('NewTech',0), ('뉴텍',0), ('매트릭스',0), ('Matrix',0), ('스타트랙',0),
             ('Star Trac',0), ('프레코',0), ('Precor',0), ('인텐사',0), ('Intenza',0), ('스테어마스터',0),('Stairmaster',0), ('맥',0), ('MAG',0), ('로그',0), ('Rougue',0),
              ('바디마스터',0),('BodyMaster',0), ('인스피레이션',0), ('Inpiration',0), ('그라운드 베이스 숄더',0), ('그라운드 베이스 스쿼드',0), ('니업 친딥 어시스트',0),
             ('DY 로우',0), ('DY',0), ('D.Y.',0), ('디와이',0), ('고정식 바벨',0), ('덤벨존',0),('덤벨렉',0), ('덤벨',1),
              ('데드리프트',0), ('데드 플랫폼',0), ('데드리프트 플랫폼',0), ('데드리프트존',0),('데드플랫폼',0), ('데드',1), ('디클라인 벤치',0), ('디클라인 체스트 프레스',0),
               ('디클라인 프레스',0), ('디클라인',1),('딥스',0), ('랫 풀 다운',0), ('랫 풀다운',0),('랫풀 다운',0), ('랫 풀',1), ('랫풀다운',0), ('랫풀',1),
                ('풀다운',1), ('랫 풀 다운',0),('트레드밀',0), ('런닝머신',0), ('러닝머신',0), ('런닝 머신',0), ('러닝 머신',0), ('트레드 밀',0),('트래드밀',0),('트래드 밀',0),
                 ('레그 익스텐션',0), ('레그익스텐션',0), ('레그 프레스',0), ('레그프레스',0), ('시티드 레그 프레스',0),('시티드 레그프레스',0), ('시티드레그프레스',0),
                  ('레그컬',0), ('레그컬',0), ('레터럴 레그 프레스',0), ('래터럴 레그 프레스',0),
             ('어시스트 친딥',0), ('닐링 레그컬',0), ('닐링레그컬',0), ('레터럴 로우',0), ('백 익스텐션',0), ('로만 체어',0),('로만체어',0), ('로우 로우',0), ('로잉 로우',0), ('로우로우',0),
              ('멀티 레이즈',0), ('멀티레이즈',0),('멀티 스테이션',0), ('시티드 로우',0), ('미드 로우',0), ('Mid-Row',0), ('로우',1), ('Row',1), ('시티드 로우',0), ('미들 로우',0), ('롱풀',0),
               ('바이셉스 컬',0), ('바이셉스',1), ('바이셉스컬',1), ('버티컬 트랙션',0), ('버티컬트랙션',0), ('버티컬 트렉션',0), ('벤치 렉',0), ('벤치랙',0), ('벤치렉',0),
                ('벤트오버 레터럴 레이즈',0), ('벤트오버 레터럴레이즈',0), ('벤트 오버 레터럴 레이즈',0), ('레이즈',1), ('벨트 스쿼트',0), ('벨트 스ㅤㅋㅝㅅ',0),
                 ('브이 스쿼트',0),('브이스쿼트',0), ('슈퍼 스쿼트',0), ('슈퍼 스ㅤㅋㅝㅅ',0), ('스미스',1), ('사선 스미스',0), ('사선쓰미스',0),('클래식스미스',0), ('사선스미스',0),
             ('레터럴 레이즈',0), ('레터럴레이즈',0), ('래터럴 레이즈',0), ('숄더 프레스',0), ('shoulder press',0), ('숄더',1),('숄더프레스',0), ('슈퍼 로잉',0), ('슈퍼로잉',0),
              ('인클라인 벤치',0), ('슈퍼 인클라인 벤치',0), ('인클라인',1),('스미스렉',0), ('스미스머신',0), ('쓰리디 스미스머신',0), ('쓰리디스미스머신',0), ('3D스미스머신',0), ('3D 스미스머신',0),
             ('사이드 레터럴 레이즈',0), ('사이드레터럴레이즈',0), ('사이드레이즈',0), ('스탠딩 힙 쓰러스트',0), ('스텝밀',0), ('천국의계단',0), ('천국의 계단',0),
             ('스탠딩 레그 컬',0), ('스탠딩 레이즈',0), ('스탠딩 숄더 프레스',0), ('스탠딩숄더',0), ('바이킹 프레스',0),
              ('스탠딩 힙 어브덕션',0), ('스탠딩 아웃타이',0), ('스탠딩 힙어브덕션',0), ('스탠딩 힙 어브덕션',0), ('스텝퍼',0), ('스트레칭 머신',0),
             ('슬링데드렉',0), ('슬링렉',0), ('슬링 렉',0), ('시티드 딥스',0), ('시티드딥스',0),
              ('시티드 레그 컬',0), ('시티드레그컬',0), ('시티드 컬',0), ('시티드 레그컬',0), ('라잉 레그 컬',0), ('라잉레그컬',0), ('싯업 벤치',0), ('싯업벤치',0), ('싯업보드',0),
               ('싸이클',0), ('입좌식싸이클',0), ('사이클',0), ('와이드 리어 풀 다운',0), ('와이드 풀다운',0), ('와이드 풀 다운',0), ('인아웃타이',0), ('이너 아웃타이',0), ('이너아웃타이',0), ('인아웃타이',0),
             ('아웃앤이너타이',0), ('이너/아웃 타이',0), ('인클라인 체스트 프레스',0), ('인클라인 체스트',1), ('플렉시블 인클라인 프레스',0), ('인클라인 프레스',1),
              ('슈퍼 인클라인 체스트 프레스',0), ('인클라인체스트',0), ('슈퍼 인클라인',1), ('정글짐',0), ('멀티정글 8스테이션',0),
               ('체스트 프레스',0), ('버티컬 체스트',0), ('체스트',1), ('체스트프레스',0), ('체스트/랫 풀 듀얼',0), ('친 앤 딥',1), ('친 앤 딥 어시스트',0), ('어시스트 풀업 딥스',0),
                ('케이블 컬',0), ('컬',1), ('케이블',1), ('티바 로우',0),
             ('파워 레그 프레스',0), ('파워 레그프레스',0), ('파워 렉',0), ('파워랙',0), ('파워렉',0), ('파워 랙',0), ('파워 렉',0), ('파워케이지',0,),
              ('파워 리프트',0), ('POWER LIFT',0), ('파워 스쿼트',0), ('파워스쿼트',0), ('펙 덱 플라이',0), ('팩 덱',1), ('펙덱플라이',0), ('체스트 플라이',0), ('펙덱 리어델트',0), ('펙덱 리어덜트',0),
               ('스쿼트',1), ('스쿼트머신',0), ('푸쉬 다운',0), ('푸쉬다운',0), ('풀 오버',0), ('풀오버',0), ('pullover',0), ('Pullover',0), ('랫 풀 다운 서큘러',0), ('풀다운 서큘러',0),
                ('프레스',0), ('프론트 레그 컬',0), ('프론 레그 컬',0), ('프론트 레그컬',0), ('프론트 레그 컬',0), ('프론트 로우',0), ('프론트 풀 다운',0), ('프론트 풀다운',0),
             ('프리처 컬 로만 체어',0), ('플랫 벤치',0), ('플랫',1), ('플랫 체스트',0), ('플렛 체스트',0), ('플레이트 로드 체스트',0), ('플렉시블 체스트 디클라인 듀얼',0),
              ('픽스드 풀 다운',0), ('픽스 풀 다운',0), ('픽스드 풀다운',0), ('하이로우',0), ('하이 로우',0), ('슈퍼 하이 로우',0), ('하프 렉',0), ('하프 랙',0), ('하프랙',0),
               ('해머 체스트 플라이',0), ('해머 플라이',0), ('해머 인클라인 플라이',0), ('플라이',1), ('인클라인 플라이',1), ('핵 스쿼트',0), ('Hack-squat',0), ('핵스쿼트',0),('핵스ㅤㅋㅝㅅ',0),
                ('핵 프레스',0), ('핵프레스',0), ('호라이즌 체스트',0),('힙 스쿼트',0), ('힙 스ㅤㅋㅝㅅ',0),
             ('힙 쓰러스트',0), ('힙쓰러스트',0), ('힙 어브덕션',0), ('어브덕션',1), ('힙 프레스',1), ('힙 어덕션',0), ('어덕션',1),
              ('앱도미널',0), ('글루트 킥백',0), ('글루트',1), ('글루트 드라이브',0), ('듀얼 풀리',0), ('크로스오버',0), ('케이블 크로스오버',0), ('크로스 오버',1), ('케이블 크로스 오버',0),
               ('리프팅 플랫폼',0), ('Lifting Platform',0), ('스탠딩 카프레이즈',0), ('케이블 체스트 프레스',0), ('케이블 체스트프레스',0), ('몬스터 글루트',0),
             ('스텝밀', 0), ('테그노짐', 0), ('M토쳐라인',0), ('엠토쳐',0),('슈퍼 하이로우 머신', 0),
             ('슈퍼 로우 머신', 0), ('바이킹 프레스 머신', 0), ('슈퍼 랫 컨버전트 머신', 0), ('아스널', 1), ('아스날', 1),
             ('스쾃프로', 0), ('파워레프팅', 0), ('벤치렉', 0),  ('퓨어스트랭스', 0),
             ('덤벨', 0), ('로잉 머신', 0), ('로잉머신', 0),
             ('에너지 음료', 0), ('단백질 쉐이크', 0), ('프로틴', 0), ('데트리프트', 0),
              ('운동기구', 0), ('운동장비', 0), ('휘트니스', 1), ('피트니스', 0),
            ('스트레칭룸', 0),('스트레칭 룸', 0),('스트레칭존', 0),
             ('스트레칭 존', 0), ('스트레칭 공간', 0), ('새삥', 0), ('새거', 0), ('샤워실', 0), ('개별 부스', 0), ('샤워부스', 0),
             ('샤워실 부스', 0), ('개별칸막이', 0), ('개인칸막이', 0), ('일인실', 0), ('1인실', 0), ('개인실', 0), ('1인 부스', 0),
             ('1인 샤워실', 0), ('클렌징오일', 0), ('샤워용품', 0), ('가글', 0), ('고데기', 0), ('화장솜', 0), ('드라이기', 0),
             ('락카', 0), ('상담사', 0), ('락커', 0), ('라커', 0), ('회원복', 0), ('리모델링', 0),
             ('갑질', 0), ('정돈', 0), ('피티쌤', 0), ('피티트레이너', 0), ('피티 선생님', 0), ('리뉴얼', 0),
             ('샤워시설', 0), ('샤워탈의실', 0),
              ('쫍', 0), ('대충', 0), ('찝어주', 0), ('집어주', 0), ('도와주', 0), ('잘해', 0), ('바글바글', 0),

             # 전반
             ('헬스장', 0),('잠하',0), ('안녕하세요',0), ('잠백이', 0),('잠백러',0), ('선착순', 0), ('입고',0), ('득근',0),
             ('질병관리청',0),('의무',0),('권고',0),('프로필',0),('인스타',0),('팔로우',0),('팔로잉',0),
             ('선팔',0),('회원권',0),('입장',0),('할인',0),

             # 운동 기구 종목 관련
             ('천국의 계단', 0), ('퓨어 스트랭스', 0), ('스쿼트', 0), ('벤치', 1), ('데드 리프트', 0),('케틀벨', 0), ('타겟팅', 0),
             ('사이벡', 0), ('파워렉', 0), ('랫풀다운', 0), ('덤밸', 0), ('울트라 스트랭스', 0), ('울트라 스트랭쓰', 0),
             ('스쿼트랙', 0), ('프리웨이트', 0), ('숄더 프레스', 0), ('숄더프레스', 0), ('체스트 프레스',0), ('체스트프레스',0),
             ('인클라인 프레스',0), ('힙스트러스트', 0), ('해머머신', 0), ('랖프', 0), ('바이킹 프레스', 0),('스텝밀', 0),
             ('부티빌더', 0), ('슈퍼 하이로우 머신', 0), ('슈퍼 로우 머신', 0), ('바이킹 프레스 머신', 0), ('슈퍼 랫 컨버전트 머신', 0),
             ('스쾃프로', 0), ('파워리프트', 0), ('파워레프팅', 0), ('벤치렉', 0), ('스쿼트', 0), ('퓨어스트랭스', 0),('퓨어 스트랭스', 0),
             ('천국의 계단', 0), ('트레드밀', 0), ('덤벨', 0), ('로잉 머신', 0), ('로잉머신', 0), ('파나타머신', 1),
             ('에너지 음료', 0), ('단백질 쉐이크', 0), ('프로틴', 0), ('데트리프트', 0), ('데드리프트', 0),('레그 익스텐션',0),('싸이벡스',0),
             ('운동기구', 0), ('운동장비', 0), ('휘트니스', 2), ('피트니스', 2),('스쿼트', 0), ('벤치', 0), ('데드 리프트', 0),

             # 운동 소도구
             ('머신', 1), ('기기', 0), ('기계', 0), ('운동기구', 0), ('장비', 0), ('도구', 0), ('덤벨', 0),('덤밸', 0), ('소도구', 0), ('바벨', 0), ('아령', 0),

             # 운동 기구
             ('랫풀다운', 0), ('로우', 1), ('체스트', 1), ('인클라인체스트', 0), ('랙', 0), ('렉', 0),('울트라스트랭쓰', 0), ('슈퍼스쿼트', 0),
             ('스쿼트랙', 0), ('프리웨이트', 0), ('어브덕션', 0), ('숄더프레스', 0),('숄더 프레스',0), ('레그 프레스', 0), ('힙스러스트', 0),
             ('체스트프레스', 0), ('풀다운', 0),('시티드로우', 0), ('시티드딥스', 0), ('레그익스텐션', 0), ('해머머신', 0), ('원판', 0),
             ('해머', 1), ('프레데터', 0),('해머 스트렝스', 0),('해머스트랭스',0), ('해머스트렝스',0),('해머스트랭스', 0),
             ('랖프', 0), ('스텝밀', 0), ('슈퍼하이로우', 0), ('슈퍼로우', 0),  ('바이킹프레스', 0), ('슈퍼랫컨버전트', 0), ('슈퍼하이로우머신', 0),
             ('슈퍼로우머신', 0), ('바이킹프레스머신', 0), ('슈퍼랫컨버전트머신', 0), ('스쾃프로', 0), ('파워리프트', 0), ('파워레프팅', 0),
             ('데트리프트', 0), ('벤치렉', 0), ('스쿼트', 0), ('벤치 프레스',0), ('벤치프레스',0), ('퓨어스트랭스', 0), ('트레드밀', 0),
             ('천국의계단', 0), ('러닝머신',0), ('런닝머신',0),('미드로우',0),('티바로우',0),('하이로우',0),

             # 운동 기구 브랜드
             ('파나타',0), ('gym80',0), ('Gym80',0), ('싸이벡스',0), ('사이벡스', 0),('너틸러스', 0),('너털 리스', 0),('렉스코', 0),
             ('아스널', 0), ('아스날', 0), ('라이프휘트니스',0),('라이프피트니스',0), ('테크노짐', 0), ('뉴텍', 0), ('브랜드',0),

             # 시설
             ('새삥', 0), ('새거', 0), ('샤워실', 0), ('개별 부스', 0), ('샤워부스', 0),
             ('샤워장', 0), ('샤워실 부스', 0), ('개별칸막이', 0), ('개인칸막이', 0), ('일인실', 0), ('1인실', 0), ('개인실', 0), ('1인 부스', 0),
             ('1인 샤워실', 0), ('클렌징오일', 0), ('샤워용품', 0), ('가글', 0), ('고데기', 0), ('화장솜', 0), ('드라이기', 0),
             ('락카', 0), ('상담사', 0), ('락커', 0), ('라커', 0), ('회원복', 0), ('리모델링', 0), ('에너지 음료', 0),
             ('갑질', 0), ('정돈', 0), ('피티쌤', 0), ('피티트레이너', 0), ('피티 선생님', 0), ('리뉴얼', 0),
             ('샤워시설', 0), ('샤워탈의실', 0), ('샤워용품', 0), ('가글', 0), ('고데기', 0), ('화장솜', 0), ('드라이기', 0),
             ('쫍', 0), ('대충', 0), ('찝어주', 0), ('바글바글', 0),('찌린내', 0),


             # 위치 관련
             ('호점',0),('역점',0),('점',1),
             ('강남역',1),('강남구',2),('강남구청',1),('강남',0),('삼성',1),('압구정',1),('신사',0),('논현',1),('신논현',1),('청담',1),('대치',1),
             ('역삼',1),('도곡',1),('개포',1),('세곡',1),('일원',1),('수서',1), ('학동',1),('봉은사',1),('언주',1),('역',1),('앞',1),

             # 단어치환도 함께 등록할 단어
             ('일일권',0),('일일',1),('일권',1),
             ('스트레칭룸', 0),('스트레칭 룸', 0), ('스트레칭 존', 0), ('스트레칭 공간', 0)]

# %%
words = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Team2_Final/word_list.xlsx')
word_list += list(zip(words['단어'], words['우선순위']))
print(word_list)
# Out:
# [('파나타', 1), ('파나타머신', 0), ('헬스장', 0), ('샤워장', 0), ('케틀벨', 0), ('타겟팅', 0), ('렉스코', 0), ('천국의 계단', 0), ('퓨어 스트랭스', 0), ('벤치', 0), ('너틸러스', 0), ('너틸 러스', 0), ('노틸러스', 0), ('Nautilus', 0), ('사이벡', 0), ('파워렉', 0), ('랫풀다운', 0), ('덤밸', 0), ('울트라 스트랭스', 0), ('울트라 스트랭쓰', 0), ('찌린내', 0), ('스쿼트랙', 0), ('프리웨이트', 0), ('힙스트러스트', 0), ('해머머신', 0), ('랖프', 0), ('해머 스트렝스', 0), ('해머스트렝스', 0), ('해머 스트랭스', 0), ('해머스트랭스', 0), ('해머', 1), ('Hammer Strength', 0), ('셀렉트', 0), ('MTS', 0), ('사이벡스', 0), ('싸이벡스', 0), ('Cybex', 0), ('싸벡', 0), ('짐80', 0), ('Gym80', 0), ('gym80', 0), ('GYM80', 0), ('테크노짐', 0), ('테크노', 1), ('Technogym', 0), ('프리모션', 0), ('라이프피트니스', 0), ('라이프', 1), ('라이프 휘트니스', 0), ('아스널스트렝스', 0), ('아스널스트랭스', 0), ('아스널 스트랭스', 0), ('아스널 스트렝스', 0), ('아스날스트렝스', 0), ('아스날스트랭스', 0), ('아스날 스트랭스', 0), ('아스날 스트렝스', 0), ('아스널', 1), ('아스날', 1), ('디렉스', 0), ('DRAX', 0), ('아틀란티스', 0), ('이카리안', 0), ('프라임', 0), ('Prime', 0), ('플렉스휘트니스', 0), ('플렉스', 1), ('울트라스트랭스', 0), ('울트라스트렝스', 0), ('호이스트', 0), ('Hoist', 0), ('부티
# ...

# %%
# 모든 사업장명을 사용자사전에 추가
# Google Drive에 저장된 엑셀 파일 경로
dba_file_path = '/content/drive/MyDrive/Colab Notebooks/Team2_Final/dba.xlsx'

# 엑셀 파일에서 데이터 읽어오기
df_dba = pd.read_excel(dba_file_path)

# '사업장명'과 '우선순위' 열의 데이터를 기반으로 word_list에 튜플 추가
word_list += list(zip(df_dba['사업장명'], df_dba['우선순위']))

# %%
make_user_dic_csv(morpheme_type="NNP", word_list=word_list, user_dic_file_name='user-nnp.csv')

# %%
# 읽기모드로 사전 각 줄 보기
with open("./user-dic/user-nnp.csv", 'r', encoding='utf-8') as f:
  file_new = f.readlines()
file_new
# Out:
# ['파나타,,,1,NNP,*,F,파나타,*,*,*,*,*\n',
#  '파나타머신,,,0,NNP,*,T,파나타머신,*,*,*,*,*\n',
#  '헬스장,,,0,NNP,*,T,헬스장,*,*,*,*,*\n',
#  '샤워장,,,0,NNP,*,T,샤워장,*,*,*,*,*\n',
#  '케틀벨,,,0,NNP,*,T,케틀벨,*,*,*,*,*\n',
#  '타겟팅,,,0,NNP,*,T,타겟팅,*,*,*,*,*\n',
#  '렉스코,,,0,NNP,*,F,렉스코,*,*,*,*,*\n',
#  '천국의 계단,,,0,NNP,*,T,천국의 계단,*,*,*,*,*\n',
#  '퓨어 스트랭스,,,0,NNP,*,F,퓨어 스트랭스,*,*,*,*,*\n',
#  '벤치,,,0,NNP,*,F,벤치,*,*,*,*,*\n',
#  '너틸러스,,,0,NNP,*,F,너틸러스,*,*,*,*,*\n',
#  '너틸 러스,,,0,NNP,*,F,너틸 러스,*,*,*,*,*\n',
#  '노틸러스,,,0,NNP,*,F,노틸러스,*,*,*,*,*\n',
#  'Nautilus,,,0,NNP,*,T,Nautilus,*,*,*,*,*\n',
#  '사이벡,,,0,NNP,*,T,사이벡,*,*,*,*,*\n',
#  '파워렉,,,0,NNP,*,T,파워렉,*,*,*,*,*\n',
#  '랫풀다운,,,0,NNP,*,T,랫풀다운,*,*,*,*,*\n',
#  '덤밸,,,0,NNP,*,T,덤밸,*,*,*,*,*\n',
#  '울트라 스트랭스,,,0,NNP,*,F,울트라 스트랭스,*,*,*,*,*\n',
#  '울트라 스트랭쓰,,,0,NNP,*,F,울트라 스트랭쓰,*,*,*,*,*\n',
#  '찌린내,,,0,NNP,*,T,찌린내,*,*,*,*,*\n',
#  '스쿼트랙,,,0,NNP,*,T,스쿼트랙,*,*,*,*,*\n',
#  '프리웨이트,,,0,NNP,*,F,프리웨이트,*,*,*,*,*\n',
#  '힙스트러스트,,,0,NNP,*,F,힙스트러스트,*,*,*,*,*\n',
# ...

# %% [markdown]
# ### 2.3 사용자 사전 반영

# %%
# 사전 생성 후 런타임 재시작 요함
import os
os.kill(os.getpid(), 9)

# %%
# 파일 목록
# %ls
# Out:
# aclocal.m4       configure.ac~  INSTALL      model.def          pos-id.def       user-user-nnp.csv
# AUTHORS          COPYING        install-sh*  NEWS               Preanalysis.csv  VA.csv
# autogen.sh*      dicrc          J.csv        NNBC.csv           README           VCN.csv
# autom4te.cache/  EC.csv         left-id.def  NNB.csv            rewrite.def      VCP.csv
# ChangeLog        EF.csv         MAG.csv      NNG.csv            right-id.def     VV.csv
# char.bin         EP.csv         MAJ.csv      NNP.csv            Symbol.csv       VX.csv
# char.def         ETM.csv        Makefile     NorthKorea.csv     sys.dic          Wikipedia.csv
# clean*           ETN.csv        Makefile.am  NP.csv             tools/           XPN.csv
# CoinedWord.csv   feature.def    Makefile.in  NR.csv             unk.def          XR.csv
# config.log       Foreign.csv    matrix.bin   Person-actor.csv   unk.dic          XSA.csv
# ...

# %%
# 디렉토리 변경
# %cd /content/mecab-ko-dic-2.1.1-20180720
# Out:
# /content/mecab-ko-dic-2.1.1-20180720

# %%
# !autoupdate configure.ac

# %%
# !bash autogen.sh
# Out:
# Looking in current directory for macros.
# configure.ac:3: warning: AM_INIT_AUTOMAKE: two- and three-arguments forms are deprecated.
# ./lib/autoconf/general.m4:2434: AC_DIAGNOSE is expanded from...
# aclocal.m4:139: AM_INIT_AUTOMAKE is expanded from...
# configure.ac:3: the top level
# configure.ac:3: warning: AM_INIT_AUTOMAKE: two- and three-arguments forms are deprecated.  For more info, see:
# configure.ac:3: https://www.gnu.org/software/automake/manual/automake.html#Modernize-AM_005fINIT_005fAUTOMAKE-invocation

# %%
# !make
# Out:
#  cd . && /bin/bash ./config.status Makefile
# config.status: creating Makefile
# make: Nothing to be done for 'all'.

# %%
# !sudo make install
# Out:
# make[1]: Entering directory '/content/mecab-ko-dic-2.1.1-20180720'
# make[1]: Nothing to be done for 'install-exec-am'.
#  /usr/bin/mkdir -p '/usr/local/lib/mecab/dic/mecab-ko-dic'
#  /usr/bin/install -c -m 644 model.bin matrix.bin char.bin sys.dic unk.dic left-id.def right-id.def rewrite.def pos-id.def dicrc '/usr/local/lib/mecab/dic/mecab-ko-dic'
# make[1]: Leaving directory '/content/mecab-ko-dic-2.1.1-20180720'

# %%
# !bash tools/add-userdic.sh
# Out:
# generating userdic...
# nnp.csv
# /content/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /content/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/nnp.csv ...
# done!
# person.csv
# /content/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /content/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/person.csv ...
# done!
# place.csv
# /content/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /content/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/place.csv ...
# done!
# user-nnp.csv
# /content/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /content/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/user-nnp.csv ...
# done!
# test -z "model.bin matrix.bin char.bin sys.dic unk.dic" || rm -f model.bin matrix.bin char.bin sys.dic unk.dic
# ...

# %%
# 사용자정의 사전 반영 확인
from konlpy.tag import Mecab

mecab = Mecab()

word_list = ['잠하! 헬스장이 별로에요', '잠백이에서 리뷰 이벤트합니다.', '잠백러 선착순 5분께 인스타 팔로잉시 증정이벤트합니다.', '바이젝월드피트니스 인사드립니다.', '해머스트랭스 재밌음 짱','강남역 바이젝 버터짐 좋아요']

for word in word_list:
  print(mecab.pos(word))
# Out:
# [('잠하', 'NNP'), ('!', 'SY'), ('헬스장', 'NNP'), ('이', 'JKS'), ('별로', 'MAG'), ('에요', 'JX')]
# [('잠백이', 'NNP'), ('에서', 'JKB'), ('리뷰', 'NNP'), ('이벤트', 'NNG'), ('합니다', 'XSV+EF'), ('.', 'SF')]
# [('잠백러', 'NNP'), ('선착순', 'NNP'), ('5', 'SN'), ('분', 'NNBC'), ('께', 'JKB'), ('인스타', 'NNP'), ('팔로잉', 'NNP'), ('시', 'NNG'), ('증정', 'NNG'), ('이벤트', 'NNG'), ('합니다', 'XSV+EF'), ('.', 'SF')]
# [('바이젝월드피트니스', 'NNP'), ('인사', 'NNG'), ('드립니다', 'VV+EF'), ('.', 'SF')]
# [('해머스트랭스', 'NNP'), ('재밌', 'VA'), ('음', 'ETN'), ('짱', 'NNG')]
# [('강남역', 'NNP'), ('바이젝 버터짐', 'NNP'), ('좋', 'VA'), ('아요', 'EC')]

# %% [markdown]
# ### 3.1 잠백이 전처리

# %% [markdown]
# #### 3.1.1 잠백이 데이터 로드

# %%
import pandas as pd

# %%
jambaekee = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Team2_Final/잠백이_전체.csv', encoding='euc-kr')
jambaekee.head(1)
# Out:
#        번호                       제목  \
# 0  878203  강남 신논현 한복판.. 3개월 11만원..
#
#                                            URL     작성자                 날짜  \
# 0  https://cafe.naver.com/formsunmyeong/878203  92ZINO  2023.11.10. 19:57
#
#                                                   본문  유형  \
# 0  찐으로 저 가격..\n신논현역 4번출구 도보 1분거리..\n운동복 수건 다줌..\n...  후기
#
#                                             네이버홈 URL
# 0  https://pcmap.place.naver.com/place/1966720325...

# %%
equipment = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Team2_Final/운동기구명_치환사전 (1).xlsx')
equipment.head()
# Out:
#    부위         통일기구명           기구1      기구2  기구3   기구4  기구5  기구6  기구7  기구8
# 0   등         DY 로우         DY 로우    DY 로우   DY  D.Y.  디와이  NaN  NaN  NaN
# 1  기타        고정식 바벨        고정식 바벨      NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 2  어깨   그라운드 베이스 숄더   그라운드 베이스 숄더      NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 3  하체  그라운드 베이스 스쿼트  그라운드 베이스 스쿼트      NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 4  기타    니업 친딥 어시스트    니업 친딥 어시스트  어시스트 친딥  NaN   NaN  NaN  NaN  NaN  NaN

# %%
#  데이터프레임 만들지 마세요!!!!
review = jambaekee['본문']
review
# Out:
# 0      찐으로 저 가격..\n신논현역 4번출구 도보 1분거리..\n운동복 수건 다줌..\n...
# 1      오랜만에 원정 헬스!!!.\n신논현 "액트짐"\n뉴텍 풀 라인에 엘리코라인..\n이...
# 2      장점\n1. 좋은 머신 많음\n2. 랙, 데드 풀랫폼 좋음.\n단점\n1. 온수 안...
# 3      안녕하세요:) 인어스휘트니스 삼성점입니다!\n잠백이 덕에 많은 정보와\n좋은 부스터...
# 4      첫날인데도 생각보다 어수선하지 않고...기구는 조금 덜 들어온듯해요\n신논현 보다 ...
#                              ...
# 108    (센터 이용 후기 관련 내용이 많지는 않아\n자유게시판으로 작성합니다)\n버터짐 &...
# 109    잠하!\n안녕하세요 잠백이 회원님들!!\n휘트니스엠 학동점입니다 :)\n휘트니스엠 ...
# 110    GRAND OPENING\nCOMING SOON\n휘트니스엠 학동점 8호점오픈예정\...
# 111    일권 5,000원 이벤트한다고하여 봉은사역에 있는 인어스휘티니스 삼성점 다녀왔습니다...
# 112    100원에 결제 후 네이버 리뷰작성하면\n쉐이커도 공짜로 핵꿀띠~\n운동경력이 이제...
# Name: 본문, Length: 113, dtype: object

# %% [markdown]
# #### 3.1.2 불용어 한글자 제거

# %%
# 불용어 제거
def remove_stopword(tokens):
    review_removed_stopword = []
    for token in tokens:
        # 토큰의 글자 수가 2글자 이상인 경우
        if 1 < len(token):
            # 토큰이 불용어가 아닌 경우만 분석용 리뷰 데이터로 포함
            if token not in list(stopword_list['불용어']):
                review_removed_stopword.append(token)
        # 토큰의 글자 수가 1글자인 경우
        else:
            # 1글자 키워드에 포함되는 경우만 분석용 리뷰 데이터로 포함
            if token in list(one_char_keyword['one_char_keyword']):
                review_removed_stopword.append(token)
    return review_removed_stopword

# %%
stopword_list= pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Team2_Final/stopword_list.xlsx')
stopword_list.tail()
# Out:
#      불용어
# 1034  이틀
# 1035  이거
# 1036  건지
# 1037  여기
# 1038  가지

# %%
one_char_keyword = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Team2_Final/one_char_list.xlsx')
one_char_keyword.head()
# Out:
#   one_char_keyword
# 0                돈
# 1                꿈
# 2                값
# 3                역
# 4                앞

# %% [markdown]
# #### 3.1.2 명사 형태소 추출

# %%
import konlpy
import jpype
import MeCab

# %%
import numpy as np
import pandas as pd
import warnings # 경고 메시지 무시
warnings.filterwarnings(action='ignore')
# 한국어 형태소 분석기 중 성능이 가장 우수한 Mecab 사용
# from konlpy.tag import Mecab
from konlpy.tag import Mecab
mecab = Mecab()
from tqdm import tqdm # 작업 프로세스 시각화
import re # 문자열 처리를 위한 정규표현식 패키지
from gensim import corpora # 단어 빈도수 계산 패키지
import gensim # LDA 모델 활용 목적
# import pyLDAvis.gensim_models # LDA 시각화용 패키지
from collections import Counter # 단어 등장 횟수 카운트

# %%
# Mecab 초기화
mecab = MeCab.Tagger()

# 명사 추출 함수 정의
def extract_nouns(text):
    node = mecab.parseToNode(text)
    nouns = []
    while node:
        if node.feature.split(',')[0] == 'NNG' or node.feature.split(',')[0] == 'NNP':
            nouns.append(node.surface)
        node = node.next
    return nouns

# '본문' 열의 각 행에 대해 명사 추출하여 '명사 토큰' 열 생성
jambaekee['명사 토큰'] = jambaekee['본문'].apply(extract_nouns)

# 결과 출력
print(jambaekee[['본문', '명사 토큰']])
# Out:
#                                                     본문  \
# 0    찐으로 저 가격..\n신논현역 4번출구 도보 1분거리..\n운동복 수건 다줌..\n...
# 1    오랜만에 원정 헬스!!!.\n신논현 "액트짐"\n뉴텍 풀 라인에 엘리코라인..\n이...
# 2    장점\n1. 좋은 머신 많음\n2. 랙, 데드 풀랫폼 좋음.\n단점\n1. 온수 안...
# 3    안녕하세요:) 인어스휘트니스 삼성점입니다!\n잠백이 덕에 많은 정보와\n좋은 부스터...
# 4    첫날인데도 생각보다 어수선하지 않고...기구는 조금 덜 들어온듯해요\n신논현 보다 ...
# ..                                                 ...
# 108  (센터 이용 후기 관련 내용이 많지는 않아\n자유게시판으로 작성합니다)\n버터짐 &...
# 109  잠하!\n안녕하세요 잠백이 회원님들!!\n휘트니스엠 학동점입니다 :)\n휘트니스엠 ...
# 110  GRAND OPENING\nCOMING SOON\n휘트니스엠 학동점 8호점오픈예정\...
# 111  일권 5,000원 이벤트한다고하여 봉은사역에 있는 인어스휘티니스 삼성점 다녀왔습니다...
# 112  100원에 결제 후 네이버 리뷰작성하면\n쉐이커도 공짜로 핵꿀띠~\n운동경력이 이제...
#
#                                                  명사 토큰
# 0    [가격, 신논현역, 출구, 거리, 운동복, 수건, 강남, 강추, 액트, 짐, 뉴텍,...
# 1    [오랜만, 원정, 헬스, 신논현, 액트, 짐, 뉴텍, 풀, 라인, 엘리, 코라, 시...
# 2    [장점, 머신, 랙, 데드, 풀, 랫, 폼, 단점, 기구, 간격, 운동, 사람, 덤...
# 3    [안녕, 인어스휘트니스 삼성점, 잠백이, 정보, 부스터, 구매, 감사, 마음, 잠백...
# ...

# %% [markdown]
# ### 3.2 잠백이 운동기구 추출

# %% [markdown]
# #### 3.2.1 기구명과 일치하는 명사 토큰 추출

# %%
# 명사 토큰 열의 리스트 속 원소가 equipment 데이터프레임의 2열부터 9열까지의 데이터와 일치하면 치환하여 '기구' 열에 입력
for i in range(len(jambaekee)):
    tokens = jambaekee.at[i, '명사 토큰']
    for col in equipment.columns[1:]:
        for token in tokens:
            if token in equipment[col].values:
                jambaekee.at[i, '기구'] = equipment.loc[equipment[col] == token, '통일기구명'].values[0]

# 결과 출력
print(jambaekee[['부위', '통일기구명', '명사 토큰', '기구']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '명사 토큰'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# 새로운 열 '기구' 생성
jambaekee['기구'] = jambaekee.apply(lambda row: [row[col] for col in equipment.columns[2:10] if row[col] in row['명사 토큰']], axis=1)

# 결과 출력
print(jambaekee[['부위', '통일기구명', '명사 토큰', '기구']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '기구1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# '명사 토큰' 열의 리스트 속 원소들 중, equipment 데이터프레임의 2열부터 9열까지의 데이터와 일치하는 경우 치환하여 '기구' 열에 입력
jambaekee['기구'] = jambaekee['명사 토큰'].apply(lambda tokens: [equipment.loc[equipment[col].isin(tokens), '통일기구명'].values.tolist() for col in equipment.columns[1:] if col in equipment.columns])

# 결과 출력
jambaekee['번호', '제목', '기구']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '명사 토큰'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# '기구' 열에 빈 중첩 리스트가 없는 행만 선택
equipped_gym = jambaekee[jambaekee['기구'].apply(lambda x: bool(x and any(x)))]

# 결과 출력
equipped_gym[['번호', '제목', '기구']]
# Out:
#          번호                                                 제목  \
# 2    853232                                    짐박스 강남 후기(1개월권)
# 4    848167                                     에이블 강남역점 간단 후기
# 5    864045      강남역 아고라피트니스에서 하는 리프팅클래스! 한체대 석학 코치에게 배워보세요!^^
# 7    793276                                         짐박스 강남점 후기
# 18   865526                           에이블짐 강남 솔직 후기 (사진 많습니다.)
# 19   764889  운동하러 가는것인가!? 미팅전에 잠깐 쉬러 가는것인가?(삼성 인터컨티넨탈 호텔 1억...
# 25   793827                                 짐박스 강남점 후기 (장단점포함)
# 28   794874                                         짐박스 강남점 후기
# 30   811617                                       헬스보이짐 학동점 후기
# 31   865588                                  헬스보이짐 학동역점 솔직한 후기
# 32   864978                                    바이젝 휘트니스 솔직한 후기
# 34   771410                        ?설날/설연휴 선릉역헬스장 ??빌리프짐??이용후기
# 37   792937         어디가서 헬창이라고 하기 부끄러워지네요...(짐박스 강남점 후기/장문 주의)
# 39   865546                                     에이블짐 강남역점 솔직후기
# ...

# %%
# '기구' 열의 중첩 리스트 내에 빈 리스트 제거 및 중복된 원소 제거
equipped_gym['기구'] = equipped_gym['기구'].apply(lambda x: list(set(item for sublist in x for item in sublist) - {''}))

# 결과 출력
equipped_gym['기구']
# Out:
# 2                              [데드리프트, 덤벨존, 사이드 레터럴 레이즈]
# 4                                               [스트레칭 존]
# 5                                           [데드리프트, 스쿼트]
# 7                              [스탠딩 숄더 프레스, 숄더 프레스, 프레스]
# 18     [와이드 리어 풀 다운, 인클라인 체스트 프레스, 풀 오버, 친 앤 딥, 듀얼 풀리...
# 19                                                 [싸이클]
# 25                         [파워 렉, 데드리프트, 핵 스쿼트, 펙 덱 플라이]
# 28     [브이 스쿼트, 핵 스쿼트, 스미스, 스쿼트, 시티드 로우, 파워 렉, 데드리프트,...
# 30                         [프레스, 플레이트 로드 체스트, 케이블 컬, 딥스]
# 31     [덤벨존, 인클라인 체스트 프레스, 체스트 프레스, 케이블 컬, 해머 체스트 플라이...
# 32                              [프론트 로우, 랫 풀 다운, 시티드 로우]
# 34                                      [스트레칭 존, 시티드 로우]
# 37     [브이 스쿼트, 파워 스쿼트, 덤벨존, 레터럴 레이즈, 핵 스쿼트, 파워 리프트, ...
# 39     [스텝밀, 스탠딩 숄더 프레스, 힙 어브덕션, 사이드 레터럴 레이즈, 풀 오버, 레...
# 41                        [체스트 프레스, 핵 스쿼트, 숄더 프레스, 풀 오버]
# 42     [스트레칭 존, 덤벨존, 스미스, 숄더 프레스, 스쿼트, 케이블 컬, 파워 레그 프...
# ...

# %%
equipped_gym.head
# Out:
# <bound method NDFrame.head of          번호                                                 제목  \
# 2    853232                                    짐박스 강남 후기(1개월권)
# 4    848167                                     에이블 강남역점 간단 후기
# 5    864045      강남역 아고라피트니스에서 하는 리프팅클래스! 한체대 석학 코치에게 배워보세요!^^
# 7    793276                                         짐박스 강남점 후기
# 18   865526                           에이블짐 강남 솔직 후기 (사진 많습니다.)
# 19   764889  운동하러 가는것인가!? 미팅전에 잠깐 쉬러 가는것인가?(삼성 인터컨티넨탈 호텔 1억...
# 25   793827                                 짐박스 강남점 후기 (장단점포함)
# 28   794874                                         짐박스 강남점 후기
# 30   811617                                       헬스보이짐 학동점 후기
# 31   865588                                  헬스보이짐 학동역점 솔직한 후기
# 32   864978                                    바이젝 휘트니스 솔직한 후기
# 34   771410                        ?설날/설연휴 선릉역헬스장 ??빌리프짐??이용후기
# 37   792937         어디가서 헬창이라고 하기 부끄러워지네요...(짐박스 강남점 후기/장문 주의)
# ...

# %%
filtered_equipped_gym = equipped_gym[['네이버홈 URL', '기구']].copy()
filtered_equipped_gym.head()
# Out:
#                                              네이버홈 URL  \
# 2   https://pcmap.place.naver.com/place/1439244830...
# 4   https://pcmap.place.naver.com/place/1958479504...
# 5   https://pcmap.place.naver.com/place/1034599129...
# 7   https://pcmap.place.naver.com/place/1439244830...
# 18  https://pcmap.place.naver.com/place/1958479504...
#
#                                                    기구
# 2                           [데드리프트, 덤벨존, 사이드 레터럴 레이즈]
# 4                                            [스트레칭 존]
# 5                                        [데드리프트, 스쿼트]
# 7                           [스탠딩 숄더 프레스, 숄더 프레스, 프레스]
# 18  [와이드 리어 풀 다운, 인클라인 체스트 프레스, 풀 오버, 친 앤 딥, 듀얼 풀리...

# %%
filtered_equipped_gym.shape
# Out:
# (51, 2)

# %%
# '네이버홈 URL' 열의 값이 같은 행끼리 '기구' 열의 값을 합치기
combined_equipment = filtered_equipped_gym.groupby('네이버홈 URL')['기구'].apply(lambda x: ', '.join(map(str, x))).reset_index()

# 결과 출력
combined_equipment
# Out:
#                                              네이버홈 URL  \
# 0   https://pcmap.place.naver.com/accommodation/11...
# 1   https://pcmap.place.naver.com/place/1032086347...
# 2   https://pcmap.place.naver.com/place/1034599129...
# 3   https://pcmap.place.naver.com/place/1159389531...
# 4   https://pcmap.place.naver.com/place/1439244830...
# 5   https://pcmap.place.naver.com/place/1644703581...
# 6   https://pcmap.place.naver.com/place/1647816099...
# 7   https://pcmap.place.naver.com/place/1650445992...
# 8   https://pcmap.place.naver.com/place/1739218540...
# 9   https://pcmap.place.naver.com/place/1891416924...
# 10  https://pcmap.place.naver.com/place/1905291994...
# 11  https://pcmap.place.naver.com/place/1941130108...
# 12  https://pcmap.place.naver.com/place/1958479504...
# 13  https://pcmap.place.naver.com/place/1970261151...
# 14  https://pcmap.place.naver.com/place/20043135/home
# 15  https://pcmap.place.naver.com/place/35149828/home
# ...

# %%
combined_equipment.shape
# Out:
# (17, 2)

# %%
combined_equipment['기구']
# Out:
# 0                                               ['싸이클']
# 1     ['레그 컬', '레그 프레스', '케이블 컬', '프레스'], ['스미스', '시...
# 2                                      ['데드리프트', '스쿼트']
# 3     ['벤트오버 레터럴 레이즈', '스탠딩 카프레이즈', '인클라인 체스트 프레스', ...
# 4     ['데드리프트', '덤벨존', '사이드 레터럴 레이즈'], ['스탠딩 숄더 프레스'...
# 5     ['프론트 로우', '랫 풀 다운', '시티드 로우'], ['와이드 풀다운', '덤...
# 6     ['스텝밀', '스트레칭 존', '힙 쓰러스트', '트레드밀', '스탠딩 레이즈',...
# 7                         ['스텝밀', '트레드밀', '싸이클', '덤벨존']
# 8     ['프레스', '플레이트 로드 체스트', '케이블 컬', '딥스'], ['덤벨존',...
# 9     ['스텝밀', '덤벨존', '사이드 레터럴 레이즈', '체스트 프레스', '케이블 ...
# 10                        ['스트레칭 존', '시티드 로우'], ['스텝밀']
# 11                                           ['스트레칭 존']
# 12    ['스트레칭 존'], ['와이드 리어 풀 다운', '인클라인 체스트 프레스', '풀...
# 13                                   ['파워 렉', '스트레칭 존']
# 14    ['스탠딩 숄더 프레스', '덤벨존', '인클라인 체스트 프레스', '레그 컬', ...
# 15    ['스텝밀'], ['인클라인 체스트 프레스', '체스트 프레스', '핵 프레스', ...
# 16                                              ['스미스']
# ...

# %%
gangnam_url = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Team2_Final/URL.xlsx')
gangnam_url.columns
# Out:
# Index(['관리번호', '검색명', '사업장명', '네이버홈 URL', '네이버리뷰 URL', '카카오리뷰 URL'], dtype='object')

# %%
# '네이버홈 URL'을 기준으로 filtered_equipped_gym과 gangnam_url 데이터프레임 병합
gym_equipment = pd.merge(combined_equipment, gangnam_url[['네이버홈 URL', '사업장명']], on='네이버홈 URL', how='left')

# 사업장명 결측치 제거
gym_equipment = gym_equipment.dropna(subset=['사업장명'])

# 열의 순서 변경
desired_order = ['사업장명', '기구', '네이버홈 URL']
gym_equipment = gym_equipment[desired_order + [col for col in gym_equipment.columns if col not in desired_order]]

# 결과 출력
gym_equipment
# Out:
#                 사업장명                                                 기구  \
# 1          와이짐 논현학동점  ['레그 컬', '레그 프레스', '케이블 컬', '프레스'], ['스미스', '시...
# 4        짐박스피트니스 강남점  ['데드리프트', '덤벨존', '사이드 레터럴 레이즈'], ['스탠딩 숄더 프레스'...
# 5        바이젝 월드 피트니스  ['프론트 로우', '랫 풀 다운', '시티드 로우'], ['와이드 풀다운', '덤...
# 6   라이크짐 24시 헬스&필라테스  ['스텝밀', '스트레칭 존', '힙 쓰러스트', '트레드밀', '스탠딩 레이즈',...
# 7         헬스보이짐 강남역점                      ['스텝밀', '트레드밀', '싸이클', '덤벨존']
# 8         헬스보이짐 학동역점  ['프레스', '플레이트 로드 체스트', '케이블 컬', '딥스'], ['덤벨존',...
# 9          헬스보이짐 선릉점  ['스텝밀', '덤벨존', '사이드 레터럴 레이즈', '체스트 프레스', '케이블 ...
# 10         빌리프짐 선릉역점                      ['스트레칭 존', '시티드 로우'], ['스텝밀']
# 11       옐로우휘트니스 대치역                                         ['스트레칭 존']
# 12         에이블짐 강남역점  ['스트레칭 존'], ['와이드 리어 풀 다운', '인클라인 체스트 프레스', '풀...
# 14              저스트짐  ['스탠딩 숄더 프레스', '덤벨존', '인클라인 체스트 프레스', '레그 컬', ...
# 15          화이트짐 강남점  ['스텝밀'], ['인클라인 체스트 프레스', '체스트 프레스', '핵 프레스', ...
# ...

# %%
# gym_equipment 데이터프레임을 엑셀 파일로 저장
gym_equipment.to_excel('gym_equipment.xlsx', index=False)

# 파일 다운로드 링크 생성
from google.colab import files
files.download('gym_equipment.xlsx')
