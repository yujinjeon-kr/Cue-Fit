# %% [markdown]
# - 주말,심야 : Y/N
# - PT 가격 : '없음'
# - 헬스 가격 없음 > 9900으로 입력

# %% [markdown]
# 추천방식
# - 상위 30개 선택 : 3순위 기준
# - 상위 10개 선택 : 2순위 기준
# - 상위 3개 선택 : 1순위 기준

# %% [markdown]
# PT 여부 선택
#  - 헬스 선택 > 이용권 > 가격 > 주말이용 > 심야이용
#  - PT 선택 > 주말이용 > 심야이용

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **PT 여부 필터링**

# %%
import pandas as pd
final_score_info = pd.read_excel('/content/gdrive/MyDrive/Score_Rate_Table.xlsx')

# %%
final_score_info.head()
# Out:
#        사업장명        기구       서비스    수건/운동복    수업(PT)        시설        주차  \
# 0  24시PT앤태닝  2.572060  0.133695  0.000000  4.839604  0.713028  0.000000
# 1      86피티  0.000000  0.000000  0.000000  2.607298  0.000000  0.000000
# 2  ACUB휘트니스  1.167183  0.336366  0.000000  5.916052  0.937963  0.258026
# 3   F45 강남점  0.229599  1.848524  0.000000  4.690072  0.609970  0.000000
# 4   F45 선릉점  0.236538  2.348950  2.294182  1.271418  2.338671  0.000000
#
#    탈의실/샤워실/사물함        총합계 사업장 유형   일일권    3개월권     1년권 심야여부 주말여부
# 0     0.000000   8.258387     PT    없음      없음      없음    Y    Y
# 1     0.000000   2.607298     PT    없음      없음      없음    Y    Y
# 2     0.096699   8.712289     헬스  9900  250000  450000    Y    Y
# 3     0.494577   7.872742     PT    없음      없음      없음    Y    Y
# 4     1.719973  10.209733     PT    없음      없음      없음    Y    Y

# %%
유형 = input("헬스 또는 PT를 입력하세요: ")
# Out:
# 헬스 또는 PT를 입력하세요: PT

# %%
if 유형 == '헬스':
    # 헬스에 대한 정보 입력 받기
    회원권 = input("회원권을 입력하세요: ")
    가격 = input("가격을 입력하세요: ")
    주말여부 = input("주말 여부를 입력하세요 (Y/N): ")
    심야여부 = input("심야 여부를 입력하세요 (Y/N): ")
    data_PT = final_score_info[final_score_info['사업장 유형'] == "헬스"]


elif 유형 == 'PT':
    # PT에 대한 정보 입력 받기
    주말여부 = input("주말 여부를 입력하세요 (Y/N): ")
    심야여부 = input("심야 여부를 입력하세요 (Y/N): ")
    data_PT = final_score_info[final_score_info['사업장 유형'] == "PT"]
# Out:
# 주말 여부를 입력하세요 (Y/N): Y
# 심야 여부를 입력하세요 (Y/N): Y

# %%
data_PT.head()
# Out:
#           사업장명        기구       서비스  수건/운동복    수업(PT)        시설        주차  \
# 2     ACUB휘트니스  1.167183  0.336366     0.0  5.916052  0.937963  0.258026
# 10   KT&G 스포테라  3.226571  0.105014     0.0  1.085271  4.702650  4.587541
# 11      MK휘트니스  2.121271  2.865809     0.0  4.965936  3.003093  0.000000
# 12  MN휘트니스 논현점  0.993034  2.194771     0.0  5.085934  1.813876  0.000000
# 13  MN휘트니스 대치점  2.385555  2.369524     0.0  3.916525  3.121148  0.189558
#
#     탈의실/샤워실/사물함        총합계 사업장 유형    일일권    3개월권      1년권 심야여부 주말여부
# 2      0.096699   8.712289     헬스   9900  250000   450000    Y    Y
# 10     0.000000  13.707047     헬스  20000  540000  1900000    N    Y
# 11     0.832785  13.788894     헬스   9800  240000   600000    Y    Y
# 12     0.812729  10.900344     헬스  10000  120000   270000    N    Y
# 13     0.800389  12.782698     헬스  10000  120000   270000    N    Y

# %% [markdown]
# **기본선택사항 필터링**

# %%
if 유형 == '헬스' :
  # 회원권에 따라 열 선택
  selected_price = data_PT[회원권]
  # 회원권 열의 값이 null인 행 제거
  data_PT = data_PT[data_PT[회원권].notna()]

  # 입력받은 가격보다 낮은 가격의 헬스장 필터링
  filtered_price = data_PT[(selected_price > 9800) & (selected_price < int(가격))]

  # 주말여부에 따라 필터링
  if 주말여부 == 'Y' :
      filtered_week = filtered_price[filtered_price['주말여부'] == 'Y']
        # 심야여부에 따라 필터링
      if 심야여부 == 'Y' :
        filtered_data = filtered_week[filtered_week['심야여부'] == 'Y']
      elif 심야여부 == 'N':
        filtered_data = filtered_week
  elif 주말여부 == 'N':
      filtered_week = filtered_price
      if 심야여부 == 'Y' :
        filtered_data = filtered_week[filtered_week['심야여부'] == 'Y']
      elif 심야여부 == 'N':
        filtered_data = filtered_week

elif 유형 =='PT' :
  # 주말여부에 따라 필터링
  if 주말여부 == 'Y' :
    filtered_week = data_PT[data_PT['주말여부'] == 'Y']
      # 심야여부에 따라 필터링
    if 심야여부 == 'Y' :
      filtered_data = filtered_week[filtered_week['심야여부'] == 'Y']
    elif 심야여부 == 'N':
      filtered_data = filtered_week
  elif 주말여부 == 'N' :
    filtered_week = data_PT
    if 심야여부 == 'Y' :
      filtered_data = filtered_week[filtered_week['심야여부'] == 'Y']
    elif 심야여부 == 'N':
      filtered_data = filtered_week

# %%
filtered_data.head()
# Out:
#           사업장명        기구       서비스    수건/운동복    수업(PT)        시설        주차  \
# 2     ACUB휘트니스  1.167183  0.336366  0.000000  5.916052  0.937963  0.258026
# 11      MK휘트니스  2.121271  2.865809  0.000000  4.965936  3.003093  0.000000
# 12  MN휘트니스 논현점  0.993034  2.194771  0.000000  5.085934  1.813876  0.000000
# 13  MN휘트니스 대치점  2.385555  2.369524  0.000000  3.916525  3.121148  0.189558
# 15     MVM 삼성점  1.356539  2.468412  0.411207  3.733993  1.913316  0.000000
#
#     탈의실/샤워실/사물함        총합계 사업장 유형    일일권    3개월권     1년권 심야여부 주말여부
# 2      0.096699   8.712289     헬스   9900  250000  450000    Y    Y
# 11     0.832785  13.788894     헬스   9800  240000  600000    Y    Y
# 12     0.812729  10.900344     헬스  10000  120000  270000    N    Y
# 13     0.800389  12.782698     헬스  10000  120000  270000    N    Y
# 15     0.905748  10.789216     헬스  22000  240000  480000    Y    Y

# %% [markdown]
# **우선순위 카테고리 필터링(추천)**

# %%
우선순위 = input("선택한 카테고리를 입력하세요 (콤마로 구분): ").split(',')
# Out:
# 선택한 카테고리를 입력하세요 (콤마로 구분): 수업(PT),시설,수건/운동복

# %%
선택카테고리 = filtered_data[['사업장명'] + 우선순위].sort_values(by=우선순위, ascending=False)

상위_30개 = 선택카테고리.sort_values(by=우선순위[0], ascending=False).head(30)

상위_10개 = 상위_30개.sort_values(by=우선순위[1],ascending=False).head(10)

상위_3개 = 상위_10개.sort_values(by=우선순위[2],ascending=False).head(3)
# Out:
#                  사업장명  탈의실/샤워실/사물함        기구    수건/운동복
# 54   라이크짐 24시 헬스&필라테스     4.201235  2.909872  6.645447
# 55               라이트짐     1.688793  2.274555  1.869784
# 276         휘트니스엠 양재점     1.640482  2.716961  1.005645

# %%
선택카테고리 = filtered_data[['사업장명'] + 우선순위]

상위_30개 = 선택카테고리.sort_values(by=우선순위[0], ascending=False).head(30)

상위_10개 = 상위_30개.sort_values(by=우선순위[1],ascending=False).head(10)

상위_3개 = 상위_10개.sort_values(by=우선순위[2],ascending=False).head(3)

# %%
상위_3개
# Out:
#                사업장명    수업(PT)        시설    수건/운동복
# 187  유레디 PT&PILATES  6.702934  2.813532  9.810925
# 173         우리동네PT샵  6.180753  2.994636  5.026511
# 118      슈퍼바디짐 압구정점  5.741881  4.646691  0.000000
