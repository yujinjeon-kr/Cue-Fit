# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 0. 세팅

# %% [markdown]
# #### 0.1 필요한 라이브러리 설치 및 임포트

# %%
# 나눔고딕 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121658 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-3_all.deb ...
# Unpacking fonts-nanum-coding (2.5-3) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-7_all.deb ...
# Unpacking fonts-nanum-eco (1.000-7) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20200506-1_all.deb ...
# Unpacking fonts-nanum-extra (20200506-1) ...
# Setting up fonts-nanum-extra (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Setting up fonts-nanum-coding (2.5-3) ...
# Setting up fonts-nanum-eco (1.000-7) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
# 나눔 폰트 설치
# !apt-get -y install fonts-nanum
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 39 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %% [markdown]
# 위 설치 코드 후 런타임 재실행

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
# 폰트 경로 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path, size=12)
fontprop_title = fm.FontProperties(fname=font_path, size=15)

# %% [markdown]
# #### 0.1 컬러맵

# %%
'''
컬러맵 종류
'Set1', 'Set2', 'Set3'
'Pastel1', 'Pastel2'
'Dark2'
'Accent'
'Paired'
'tab10', 'tab20', 'tab20b', 'tab20c'
'cubehelix'
'''
# Out:
# "\n컬러맵 종류\n'Set1'\n'Set2'\n'Set3'\n'Pastel1'\n'Pastel2'\n'Dark2'\n'Accent'\n'Paired'\n'tab10'\n'tab20'\n'tab20b'\n'tab20c'\n'cubehelix'\n"

# %%
palette1 = sns.color_palette('Set1', n_colors=12) # pastel Set3
palette1
# Out:
# [(0.8941176470588236, 0.10196078431372549, 0.10980392156862745),
#  (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
#  (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
#  (0.596078431372549, 0.3058823529411765, 0.6392156862745098),
#  (1.0, 0.4980392156862745, 0.0),
#  (1.0, 1.0, 0.2),
#  (0.6509803921568628, 0.33725490196078434, 0.1568627450980392),
#  (0.9686274509803922, 0.5058823529411764, 0.7490196078431373),
#  (0.6, 0.6, 0.6),
#  (0.8941176470588236, 0.10196078431372549, 0.10980392156862745),
#  (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
#  (0.30196078431372547, 0.6862745098039216, 0.2901960784313726)]

# %%
palette2 = sns.color_palette('Set2', n_colors=12) # pastel Set3
palette2
# Out:
# [(0.4, 0.7607843137254902, 0.6470588235294118),
#  (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
#  (0.5529411764705883, 0.6274509803921569, 0.796078431372549),
#  (0.9058823529411765, 0.5411764705882353, 0.7647058823529411),
#  (0.6509803921568628, 0.8470588235294118, 0.32941176470588235),
#  (1.0, 0.8509803921568627, 0.1843137254901961),
#  (0.8980392156862745, 0.7686274509803922, 0.5803921568627451),
#  (0.7019607843137254, 0.7019607843137254, 0.7019607843137254),
#  (0.4, 0.7607843137254902, 0.6470588235294118),
#  (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
#  (0.5529411764705883, 0.6274509803921569, 0.796078431372549),
#  (0.9058823529411765, 0.5411764705882353, 0.7647058823529411)]

# %%
palette3 = sns.color_palette('Set3', n_colors=12) # pastel Set3
palette3
# Out:
# [(0.5529411764705883, 0.8274509803921568, 0.7803921568627451),
#  (1.0, 1.0, 0.7019607843137254),
#  (0.7450980392156863, 0.7294117647058823, 0.8549019607843137),
#  (0.984313725490196, 0.5019607843137255, 0.4470588235294118),
#  (0.5019607843137255, 0.6941176470588235, 0.8274509803921568),
#  (0.9921568627450981, 0.7058823529411765, 0.3843137254901961),
#  (0.7019607843137254, 0.8705882352941177, 0.4117647058823529),
#  (0.9882352941176471, 0.803921568627451, 0.8980392156862745),
#  (0.8509803921568627, 0.8509803921568627, 0.8509803921568627),
#  (0.7372549019607844, 0.5019607843137255, 0.7411764705882353),
#  (0.8, 0.9215686274509803, 0.7725490196078432),
#  (1.0, 0.9294117647058824, 0.43529411764705883)]

# %%
palette4 = sns.color_palette('Pastel1', n_colors=9) # pastel Set3
palette4
# Out:
# [(0.984313725490196, 0.7058823529411765, 0.6823529411764706),
#  (0.7019607843137254, 0.803921568627451, 0.8901960784313725),
#  (0.8, 0.9215686274509803, 0.7725490196078432),
#  (0.8705882352941177, 0.796078431372549, 0.8941176470588236),
#  (0.996078431372549, 0.8509803921568627, 0.6509803921568628),
#  (1.0, 1.0, 0.8),
#  (0.8980392156862745, 0.8470588235294118, 0.7411764705882353),
#  (0.9921568627450981, 0.8549019607843137, 0.9254901960784314),
#  (0.9490196078431372, 0.9490196078431372, 0.9490196078431372)]

# %%
palette5 = sns.color_palette('Pastel2', n_colors=8) # pastel Set3
palette5
# Out:
# [(0.7019607843137254, 0.8862745098039215, 0.803921568627451),
#  (0.9921568627450981, 0.803921568627451, 0.6745098039215687),
#  (0.796078431372549, 0.8352941176470589, 0.9098039215686274),
#  (0.9568627450980393, 0.792156862745098, 0.8941176470588236),
#  (0.9019607843137255, 0.9607843137254902, 0.788235294117647),
#  (1.0, 0.9490196078431372, 0.6823529411764706),
#  (0.9450980392156862, 0.8862745098039215, 0.8),
#  (0.8, 0.8, 0.8)]

# %%
palette6 = sns.color_palette('Dark2', n_colors=12) # pastel Set3
palette6
# Out:
# [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
#  (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
#  (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
#  (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
#  (0.4, 0.6509803921568628, 0.11764705882352941),
#  (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
#  (0.6509803921568628, 0.4627450980392157, 0.11372549019607843),
#  (0.4, 0.4, 0.4),
#  (0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
#  (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
#  (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
#  (0.9058823529411765, 0.1607843137254902, 0.5411764705882353)]

# %%
palette6 = sns.color_palette('Dark2', n_colors=12) # pastel Set3
palette6
# Out:
# [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
#  (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
#  (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
#  (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
#  (0.4, 0.6509803921568628, 0.11764705882352941),
#  (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
#  (0.6509803921568628, 0.4627450980392157, 0.11372549019607843),
#  (0.4, 0.4, 0.4),
#  (0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
#  (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
#  (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
#  (0.9058823529411765, 0.1607843137254902, 0.5411764705882353)]

# %%
palette7 = sns.color_palette('Accent', n_colors=12) # pastel Set3
palette7
# Out:
# [(0.4980392156862745, 0.788235294117647, 0.4980392156862745),
#  (0.7450980392156863, 0.6823529411764706, 0.8313725490196079),
#  (0.9921568627450981, 0.7529411764705882, 0.5254901960784314),
#  (1.0, 1.0, 0.6),
#  (0.2196078431372549, 0.4235294117647059, 0.6901960784313725),
#  (0.9411764705882353, 0.00784313725490196, 0.4980392156862745),
#  (0.7490196078431373, 0.3568627450980392, 0.09019607843137253),
#  (0.4, 0.4, 0.4),
#  (0.4980392156862745, 0.788235294117647, 0.4980392156862745),
#  (0.7450980392156863, 0.6823529411764706, 0.8313725490196079),
#  (0.9921568627450981, 0.7529411764705882, 0.5254901960784314),
#  (1.0, 1.0, 0.6)]

# %%
palette8 = sns.color_palette('Paired', n_colors=12)
palette8
# Out:
# [(0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  (0.2, 0.6274509803921569, 0.17254901960784313),
#  (0.984313725490196, 0.6039215686274509, 0.6),
#  (0.8901960784313725, 0.10196078431372549, 0.10980392156862745),
#  (0.9921568627450981, 0.7490196078431373, 0.43529411764705883),
#  (1.0, 0.4980392156862745, 0.0),
#  (0.792156862745098, 0.6980392156862745, 0.8392156862745098),
#  (0.41568627450980394, 0.23921568627450981, 0.6039215686274509),
#  (1.0, 1.0, 0.6),
#  (0.6941176470588235, 0.34901960784313724, 0.1568627450980392)]

# %%
palette9 = sns.color_palette('tab10', n_colors=12)
palette9
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529),
#  (0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725)]

# %%
palette10 = sns.color_palette('tab20', n_colors=12)
palette10
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (0.6823529411764706, 0.7803921568627451, 0.9098039215686274),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (1.0, 0.7333333333333333, 0.47058823529411764),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.596078431372549, 0.8745098039215686, 0.5411764705882353),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (1.0, 0.596078431372549, 0.5882352941176471),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.7725490196078432, 0.6901960784313725, 0.8352941176470589),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.7686274509803922, 0.611764705882353, 0.5803921568627451)]

# %%
palette11 = sns.color_palette('tab20b', n_colors=12)
palette11
# Out:
# [(0.2235294117647059, 0.23137254901960785, 0.4745098039215686),
#  (0.3215686274509804, 0.32941176470588235, 0.6392156862745098),
#  (0.4196078431372549, 0.43137254901960786, 0.8117647058823529),
#  (0.611764705882353, 0.6196078431372549, 0.8705882352941177),
#  (0.38823529411764707, 0.4745098039215686, 0.2235294117647059),
#  (0.5490196078431373, 0.6352941176470588, 0.3215686274509804),
#  (0.7098039215686275, 0.8117647058823529, 0.4196078431372549),
#  (0.807843137254902, 0.8588235294117647, 0.611764705882353),
#  (0.5490196078431373, 0.42745098039215684, 0.19215686274509805),
#  (0.7411764705882353, 0.6196078431372549, 0.2235294117647059),
#  (0.9058823529411765, 0.7294117647058823, 0.3215686274509804),
#  (0.9058823529411765, 0.796078431372549, 0.5803921568627451)]

# %%
palette11 = sns.color_palette('tab20c', n_colors=12)
palette11
# Out:
# [(0.19215686274509805, 0.5098039215686274, 0.7411764705882353),
#  (0.4196078431372549, 0.6823529411764706, 0.8392156862745098),
#  (0.6196078431372549, 0.792156862745098, 0.8823529411764706),
#  (0.7764705882352941, 0.8588235294117647, 0.9372549019607843),
#  (0.9019607843137255, 0.3333333333333333, 0.050980392156862744),
#  (0.9921568627450981, 0.5529411764705883, 0.23529411764705882),
#  (0.9921568627450981, 0.6823529411764706, 0.4196078431372549),
#  (0.9921568627450981, 0.8156862745098039, 0.6352941176470588),
#  (0.19215686274509805, 0.6392156862745098, 0.32941176470588235),
#  (0.4549019607843137, 0.7686274509803922, 0.4627450980392157),
#  (0.6313725490196078, 0.8509803921568627, 0.6078431372549019),
#  (0.7803921568627451, 0.9137254901960784, 0.7529411764705882)]

# %%
palette30 = sns.color_palette('cubehelix', n_colors=30)
palette30
# Out:
# [(0.04821681803535116, 0.01872412818265829, 0.053275453666033826),
#  (0.08189796242653116, 0.04329494698864347, 0.11483403839700104),
#  (0.09998352692085306, 0.07565501051639596, 0.17714719988612818),
#  (0.10392854711056776, 0.12195583993692868, 0.23890270624183174),
#  (0.09756266684989742, 0.17078460296738385, 0.2795691482206972),
#  (0.08811505493374118, 0.22444091969962535, 0.30274693905036704),
#  (0.0822914940822713, 0.27972613953271874, 0.30730403748717383),
#  (0.08801401599773798, 0.33940630645391495, 0.2924494837317682),
#  (0.10962993366743318, 0.386432823959482, 0.2664684056488389),
#  (0.14993280529807912, 0.424934471382481, 0.23524736151160613),
#  (0.20939050075035193, 0.4532599402265316, 0.20636740939874193),
#  (0.29648110668342353, 0.47258417382683937, 0.18605520738573791),
#  (0.3868579298796123, 0.4798293942522737, 0.18591761462348488),
#  (0.48292995666454097, 0.4801858681801365, 0.2071965590118011),
# ...

# %% [markdown]
# ### 1. 데이터 로드

# %%
rec_score = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Team2_Final/추천점수_테이블_최종_1215.xlsx')
hour = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Team2_Final/네이버_영업시간.xlsx')
add_facility = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Team2_Final/네이버_사업장유형.xlsx')
rate = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Team2_Final/네이버_가격정보.xlsx')

# %%
rec_score = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Team2_Final/추천점수_테이블_최종_1215.xlsx')
rec_score.tail()
# Out:
#               사업장명        기구       서비스  수건/운동복    수업(PT)        시설        주차  \
# 279   휴메이크휘트니스 대치점  1.383773  2.715552     0.0  5.267151  3.237642  0.168562
# 280  휴메이크휘트니스 선정릉점  1.743977  2.926380     0.0  5.113177  2.850707  0.000000
# 281   휴메이크휘트니스 역삼점  1.562371  4.396903     0.0  3.116372  4.079885  0.000000
# 282            휴즈짐  1.176132  1.302837     0.0  3.731451  1.977260  0.000000
# 283           힙업학원  0.000000  0.000000     0.0  5.183036  3.996605  0.000000
#
#      탈의실/샤워실/사물함        총합계
# 279     1.129399  13.902079
# 280     2.693079  15.327319
# 281     2.775572  15.931103
# 282     1.649652   9.837331
# 283     0.000000   9.179641

# %%
rec_score.describe()
# Out:
#                기구         서비스      수건/운동복      수업(PT)          시설          주차  \
# count  284.000000  284.000000  284.000000  284.000000  284.000000  284.000000
# mean     1.062935    1.543593    0.778821    4.361536    2.075888    0.229752
# std      1.212927    1.107356    1.949562    1.961923    1.495972    0.836473
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.237194    0.727649    0.000000    2.986254    0.933614    0.000000
# 50%      0.776408    1.334141    0.000000    4.564535    1.760111    0.000000
# 75%      1.435494    2.172152    0.358354    5.783027    2.986234    0.124157
# max     10.000000   10.000000   10.000000   10.000000   10.000000   10.000000
#
#        탈의실/샤워실/사물함         총합계
# count   284.000000  284.000000
# mean      0.992185   11.044710
# std       1.414542    3.800480
# min       0.000000    2.607298
# 25%       0.000000    8.352165
# 50%       0.487500   10.407828
# 75%       1.467661   13.047691
# ...

# %%
hour.head()
# Out:
#           사업장명     평일 개점     평일 폐점 토요일 일요일 연중무휴
# 0     ACUB휘트니스  06:00:00  00:00:00   Y   N    N
# 1  스포애니 강남역1호점  06:00:00  00:00:00   Y   N    N
# 2    스포애니 논현역점  06:00:00  00:00:00   Y   Y    N
# 3    스포애니 대치동점  07:00:00  23:00:00   Y   N    N
# 4    스포애니 선릉역점  08:00:00  23:00:00   Y   Y    N

# %%
add_facility.head()
# Out:
#           사업장명 사업장 유형 체인점 여성전용 반려동물 동반 부가_GX 부가_필라테스 부가_요가 부가_골프 부가_재활 부가_격투기  \
# 0     ACUB휘트니스     헬스   N    N       Y   NaN     NaN   NaN   NaN   NaN    NaN
# 1  스포애니 강남역1호점     헬스   Y    N       N   NaN     NaN   NaN   NaN   NaN    NaN
# 2    스포애니 논현역점     헬스   Y    N       N   NaN     NaN   NaN   NaN   NaN    NaN
# 3    스포애니 대치동점     헬스   Y    N       N   NaN     NaN   NaN   NaN   NaN    NaN
# 4    스포애니 선릉역점     헬스   Y    N       N   NaN     NaN   NaN   NaN   NaN    NaN
#
#   부가_선수관리 부가_사우나
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN

# %%
rate.head()
# Out:
#           사업장명    일일권    3개월권     1년권
# 0     ACUB휘트니스   9900  250000  450000
# 1  스포애니 강남역1호점  10000   90000  240000
# 2    스포애니 논현역점  10000   90000  240000
# 3    스포애니 대치동점  10000   90000  240000
# 4    스포애니 선릉역점  10000   90000  240000

# %% [markdown]
# ### 2. 추천점수 시각화 rec_score

# %% [markdown]
# #### 2-1. 카테고리 별 추천점수 (바이올린 플롯)

# %%
# 바이올린 플롯 그리기
plt.figure(figsize=(12, 8))
sns.violinplot(data=rec_score.iloc[:, :-1], inner="quartile", palette='Pastel1')  # "inner" 매개변수를 통해 중앙값과 사분위수를 표시합니다. colormap='Set3'
plt.title('카테고리별 추천점수', fontproperties=fontprop)
plt.xticks(fontproperties=fontprop)

# 가로 그리드 추가
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# #### 2.2 각 카테고리 부문 상위 10개 헬스장(막대그래프)

# %%
# '사업장명' 열을 인덱스로 설정
rec_score = rec_score.set_index('사업장명')

# %%
# '서비스' 열 기준으로 상위 10개 데이터 선택
top_10_total = rec_score.nlargest(10, '총합계')

# 각 열별로 막대 그래프 그리기
plt.figure(figsize=(7, 4))
plt.bar(top_10_total.index, top_10_total['총합계'],color=palette3[8], edgecolor='gray')

plt.xlabel('사업장명', fontproperties=fontprop)
plt.ylabel('추천점수', fontproperties=fontprop)
plt.title('추천점수 상위 10개 헬스장', fontproperties=fontprop)
plt.xticks(rotation=45, ha='right', fontproperties=fontprop)
plt.yticks(fontproperties=fontprop)
plt.show()

# %%
# '총합계' 열 기준으로 상위 10개 데이터 선택
top_10_equip = rec_score.nlargest(10, '기구')

# Bar Chart for '서비스' column
plt.figure(figsize=(7, 4))
plt.bar(top_10_equip.index, top_10_equip['기구'], color=palette4[0], edgecolor='gray')
plt.xlabel('사업장명', fontproperties=fontprop)
plt.ylabel('기구 점수', fontproperties=fontprop)
plt.title('기구 부문 상위 10개 헬스장', fontproperties=fontprop)
plt.xticks(rotation=45, ha='right', fontproperties=fontprop)
plt.yticks(fontproperties=fontprop)
plt.show()

# %%
# '서비스' 열 기준으로 상위 10개 데이터 선택
top_10_service = rec_score.nlargest(10, '서비스')

# Bar Chart for '서비스' column
plt.figure(figsize=(7, 4))
plt.bar(top_10_service.index, top_10_service['서비스'], color=palette3[1], edgecolor='gray')
plt.xlabel('사업장명', fontproperties=fontprop)
plt.ylabel('서비스 점수', fontproperties=fontprop)
plt.title('서비스 부문 상위 10개 헬스장', fontproperties=fontprop)
plt.xticks(rotation=45, ha='right', fontproperties=fontprop)
plt.yticks(fontproperties=fontprop)
plt.show()

# %%
# '수건/운동복' 열 기준으로 상위 10개 데이터 선택
top_10_service = rec_score.nlargest(10, '수건/운동복')

# Bar Chart for '수건/운동복' column
plt.figure(figsize=(7, 4))
plt.bar(top_10_service.index, top_10_service['수건/운동복'], color=palette3[2], edgecolor='gray')
plt.xlabel('사업장명', fontproperties=fontprop)
plt.ylabel('수건/운동복 점수', fontproperties=fontprop)
plt.title('수건/운동복 부문 상위 10개 헬스장', fontproperties=fontprop)
plt.xticks(rotation=45, ha='right', fontproperties=fontprop)
plt.yticks(fontproperties=fontprop)
plt.show()

# %%
# '수업(PT)' 열 기준으로 상위 10개 데이터 선택
top_10_service = rec_score.nlargest(10, '수업(PT)')

# Bar Chart for '수업(PT)' column
plt.figure(figsize=(7, 4))
plt.bar(top_10_service.index, top_10_service['수업(PT)'], color=palette3[3], edgecolor='gray')
plt.xlabel('사업장명', fontproperties=fontprop)
plt.ylabel('수업(PT) 점수', fontproperties=fontprop)
plt.title('수업(PT) 부문 상위 10개 헬스장', fontproperties=fontprop)
plt.xticks(rotation=45, ha='right', fontproperties=fontprop)
plt.yticks(fontproperties=fontprop)
plt.show()

# %%
# '시설' 열 기준으로 상위 10개 데이터 선택
top_10_service = rec_score.nlargest(10, '시설')

# Bar Chart for '서비스' column
plt.figure(figsize=(7, 4))
plt.bar(top_10_service.index, top_10_service['시설'], color=palette3[4], edgecolor='gray')
plt.xlabel('사업장명', fontproperties=fontprop)
plt.ylabel('시설 점수', fontproperties=fontprop)
plt.title('시설 부문 상위 10개 헬스장', fontproperties=fontprop)
plt.xticks(rotation=45, ha='right', fontproperties=fontprop)
plt.yticks(fontproperties=fontprop)
plt.show()

# %%
# '주차' 열 기준으로 상위 10개 데이터 선택
top_10_park = rec_score.nlargest(10, '주차')

# 각 열별로 막대 그래프 그리기
plt.figure(figsize=(7, 4))

for col in top_10_park.columns:
    plt.bar(top_10_park.index, top_10_park['주차'], color=palette3[5], edgecolor='gray')

plt.xlabel('사업장명', fontproperties=fontprop)
plt.ylabel('주차 점수', fontproperties=fontprop)
plt.title('주차 부문 상위 10개 헬스장', fontproperties=fontprop)
plt.xticks(rotation=45, ha='right', fontproperties=fontprop)
plt.yticks(fontproperties=fontprop)
plt.show()

# %%
# '탈의실/샤워실/사물함' 열 기준으로 상위 10개 데이터 선택
top_10_facility = rec_score.nlargest(10, '탈의실/샤워실/사물함')

# 각 열별로 막대 그래프 그리기
plt.figure(figsize=(7, 4))

for col in top_10_facility.columns:
    plt.bar(top_10_facility.index, top_10_facility['탈의실/샤워실/사물함'], color=palette3[6], edgecolor='gray')

plt.xlabel('사업장명', fontproperties=fontprop)
plt.ylabel('탈의실/샤워실/사물함 점수', fontproperties=fontprop)
plt.title('탈의실/샤워실/사물함 부문 상위 10개 헬스장', fontproperties=fontprop)
plt.xticks(rotation=45, ha='right', fontproperties=fontprop)
plt.yticks(fontproperties=fontprop)
plt.show()

# %% [markdown]
# #### 2.3 추천점수 상위10개 헬스장의 카테고리별 점수 점유율 (중첩막대그래프)

# %%
# '총합계' 열 기준으로 상위 10개 데이터 선택
top_10_total = rec_score.nlargest(10, '총합계')

# %%
# '총합계' 열 기준으로 상위 10개 데이터 선택
top_10_total = rec_score.nlargest(10, '총합계')

# 행과 열을 바꾼 새로운 데이터프레임 생성
top_10_total_switch = top_10_total.transpose()
top_10_total_switch = top_10_total_switch.iloc[0:-1,:]
top_10_total_switch
# Out:
#                   43         127       138          230          190  \
# 사업장명           더원짐 대치  스포애니 논현역점    싸다휘트니스  투엑스휘트니스 개포점  인어스휘트니스 삼성점
# 기구           1.802047   1.652207  1.524842     4.212281     1.863006
# 서비스          2.104256    2.68864  0.170407     3.655598     2.647204
# 수건/운동복       8.409547   9.718943  8.585721     8.621804         10.0
# 수업(PT)       2.356611   1.735218  2.339421     0.663505     0.900783
# 시설           6.356953   3.549622  1.198636     4.388587     3.334207
# 주차                0.0   1.636188       0.0          0.0          0.0
# 탈의실/샤워실/사물함   7.82247   4.451845      10.0     0.917815     3.197217
#
#                           54          84              187       263       163
# 사업장명         라이크짐 24시 헬스&필라테스  바디스페이스 논현점  유레디 PT&PILATES   함스짐 강남점    엑슬휘트니스
# 기구                   2.909872     1.54607             0.0  1.274038  0.939573
# 서비스                  1.617711    2.800264        0.425721  4.013117  2.226198
# ...

# %%
# Select columns from the 2nd to the 8th
columns_to_plot = top_10_total_switch.columns[0:11]

# Stacked Bar Chart using Seaborn
plt.figure(figsize=(10, 6))

top_10_total_switch.T.plot(kind='barh', stacked=True, color=palette4, ax=plt.gca())  # palette7   colormap='Set3'

plt.xlabel('추천점수', fontproperties=fontprop)
plt.ylabel('사업장명', fontproperties=fontprop)
plt.title('추천점수 상위 10개 사업장의 카테고리별 점유', fontproperties=fontprop_title)
plt.xticks(fontproperties=fontprop)
plt.yticks(fontproperties=fontprop)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontprop, fontsize='xxxx-small') # , prop=fontprop title='카테고리',
plt.show()

# %% [markdown]
# ### 3. 사업장유형 시각화 add_facility

# %% [markdown]
# #### 3.1 데이터 보기

# %%
add_facility.tail()
# Out:
#            사업장명 사업장 유형 체인점 여성전용 반려동물 동반 부가_GX 부가_필라테스 부가_요가 부가_골프  부가_재활  \
# 333       유휘트니스     헬스   Y    N       N     Y     NaN   NaN      Y   NaN
# 334         위너즈     헬스   N    N       Y   NaN     NaN   NaN    NaN   NaN
# 335  바디스페이스 논현점     헬스   Y    N       N   NaN     NaN   NaN    NaN   NaN
# 336  바디스페이스 선릉점     헬스   Y    N       N   NaN     NaN   NaN    NaN   NaN
# 337         젠틀짐     헬스   N    N       N   NaN     NaN   NaN    NaN   NaN
#
#     부가_격투기 부가_선수관리 부가_사우나
# 333    NaN     NaN    NaN
# 334      Y     NaN    NaN
# 335    NaN     NaN    NaN
# 336    NaN     NaN    NaN
# 337    NaN     NaN    NaN

# %%
gx = add_facility['부가_GX'].value_counts().get('Y', 0)
pilates = add_facility['부가_필라테스'].value_counts().get('Y', 0)
yoga = add_facility['부가_요가'].value_counts().get('Y', 0)
golf = add_facility['부가_골프'].value_counts().get('Y', 0)
rehab = add_facility['부가_재활'].value_counts().get('Y', 0)
martial = add_facility['부가_격투기'].value_counts().get('Y', 0)
athlete = add_facility['부가_선수관리'].value_counts().get('Y', 0)
sauna = add_facility['부가_사우나'].value_counts().get('Y', 0)

print(f'부가_GX 열에서 Y 값의 갯수: {gx}')
print(f'부가_필라테스 열에서 Y 값의 갯수: {pilates}')
print(f'부가_요가 열에서 Y 값의 갯수: {yoga}')
print(f'부가_골프 열에서 Y 값의 갯수: {golf}')
print(f'부가_재활 열에서 Y 값의 갯수: {rehab}')
print(f'부가_격투기 열에서 Y 값의 갯수: {martial}')
print(f'부가_선수관리 열에서 Y 값의 갯수: {athlete}')
print(f'부가_사우나 열에서 Y 값의 갯수: {sauna}')
# Out:
# 부가_GX 열에서 Y 값의 갯수: 10
# 부가_필라테스 열에서 Y 값의 갯수: 18
# 부가_요가 열에서 Y 값의 갯수: 2
# 부가_골프 열에서 Y 값의 갯수: 15
# 부가_재활 열에서 Y 값의 갯수: 12
# 부가_격투기 열에서 Y 값의 갯수: 2
# 부가_선수관리 열에서 Y 값의 갯수: 4
# 부가_사우나 열에서 Y 값의 갯수: 5

# %%
# Assuming columns 5 to 12 (0-based index) are the columns of interest
column_indices = list(range(5, 13))

for idx, col_name in enumerate(add_facility.columns[column_indices]):
    count_y = add_facility[col_name].value_counts().get('Y', 0)
    print(f'{col_name} Y 값의 갯수: {count_y}')
# Out:
# 부가_GX Y 값의 갯수: 10
# 부가_필라테스 Y 값의 갯수: 18
# 부가_요가 Y 값의 갯수: 2
# 부가_골프 Y 값의 갯수: 15
# 부가_재활 Y 값의 갯수: 12
# 부가_격투기 Y 값의 갯수: 2
# 부가_선수관리 Y 값의 갯수: 4
# 부가_사우나 Y 값의 갯수: 5

# %%
columns_to_check = ['부가_GX', '부가_필라테스', '부가_요가', '부가_골프', '부가_재활', '부가_격투기', '부가_선수관리', '부가_사우나']

for column_name in columns_to_check:
    if column_name in add_facility.columns:
        count_y = add_facility[column_name].value_counts().get('Y', 0)
        print(f'{column_name} 열에서 Y 값의 갯수: {count_y}')
    else:
        print(f'{column_name} 열이 존재하지 않습니다.')
# Out:
# 부가_GX 열에서 Y 값의 갯수: 10
# 부가_필라테스 열에서 Y 값의 갯수: 18
# 부가_요가 열에서 Y 값의 갯수: 2
# 부가_골프 열이 존재하지 않습니다.
# 부가_재활 열에서 Y 값의 갯수: 12
# 부가_격투기 열에서 Y 값의 갯수: 2
# 부가_선수관리 열에서 Y 값의 갯수: 4
# 부가_사우나 열에서 Y 값의 갯수: 5

# %%
add_facility['사업장 유형'].unique()
# Out:
# array(['헬스', 'PT', 'PT - 그룹'], dtype=object)

# %% [markdown]
# #### 3.2 사업자 유형 (원그래프)

# %%
plt.rc('font', family='NanumGothic')

# Seaborn에서도 한글 폰트 설정
sns.set(font=fontprop.get_name())

# 2x2 형태의 subplot 생성
fig, axes = plt.subplots(2, 2, figsize=(6, 6))

# 각 subplot에 대한 Pie Chart 그리기
for i, ax in enumerate(axes.flatten()):
    if i == 0:
        data = add_facility['사업장 유형']
        title = '사업장 유형'
        colors = [palette4[2], palette4[3], palette4[5]]
    elif i == 1:
        data = add_facility['체인점']
        title = '체인점'
        colors = [palette4[0], palette4[1]]
    elif i == 2:
        data = add_facility['여성전용']
        title = '여성전용'
        colors = [palette4[0], palette4[1]]
    else:
        data = add_facility['반려동물 동반']
        title = '반려동물 동반'
        colors = [palette4[0], palette4[1]]

    data.value_counts().plot(kind='pie', autopct='%1.2f%%', startangle=90, colors=colors, ax=ax)
    ax.set_title(title, fontproperties=fontprop)
    ax.set_ylabel('')  # y축 레이블 지우기

# 전체 Figure에 대한 타이틀
fig.suptitle('사업장 유형 및 특성', fontproperties=fontprop_title, fontsize=15)

# 레이아웃 조정
plt.tight_layout()

# 모든 subplot 함께 출력
plt.show()

# %%
plt.rc('font', family='NanumGothic')

# Seaborn에서도 한글 폰트 설정
sns.set(font=fontprop.get_name())

# 2x2 형태의 subplot 생성
fig, axes = plt.subplots(1, 2, figsize=(6, 3))

# 각 subplot에 대한 Pie Chart 그리기
for i, ax in enumerate(axes.flatten()):
    if i == 0:
        data = add_facility['사업장 유형']
        title = '사업장 유형'
        colors = [palette4[2], palette4[3], palette4[5]]
    else:
        data = add_facility['체인점']
        title = '체인점'
        colors = [palette4[0], palette4[1]]

    data.value_counts().plot(kind='pie', autopct='%1.2f%%', startangle=90, colors=colors, ax=ax)
    ax.set_title(title, fontproperties=fontprop)
    ax.set_ylabel('')  # y축 레이블 지우기

# 전체 Figure에 대한 타이틀
fig.suptitle('사업장 유형 및 체인점 여부', fontproperties=fontprop_title, fontsize=15)

# 레이아웃 조정
plt.tight_layout()

# 모든 subplot 함께 출력
plt.show()

# %%
plt.rc('font', family='NanumGothic')

# Seaborn에서도 한글 폰트 설정
sns.set(font=fontprop.get_name())

# 2x2 형태의 subplot 생성
fig, axes = plt.subplots(1, 2, figsize=(6, 3))

# 각 subplot에 대한 Pie Chart 그리기
for i, ax in enumerate(axes.flatten()):
    if i == 0:
        data = add_facility['여성전용']
        title = '여성전용'
        colors = [palette4[0], palette4[1]]
    else:
        data = add_facility['반려동물 동반']
        title = '반려동물 동반'
        colors = [palette4[0], palette4[1]]

    data.value_counts().plot(kind='pie', autopct='%1.2f%%', startangle=90, colors=colors, ax=ax)
    ax.set_title(title, fontproperties=fontprop)
    ax.set_ylabel('')  # y축 레이블 지우기

# 전체 Figure에 대한 타이틀
fig.suptitle('여성전용과 반려동물 동반 여부', fontproperties=fontprop_title, fontsize=15)

# 레이아웃 조정
plt.tight_layout()

# 모든 subplot 함께 출력
plt.show()

# %% [markdown]
# ### 4. 영업시간 hour

# %% [markdown]
# #### 4.1 영업시간 보기

# %%
hour.head()
# Out:
#           사업장명     평일 개점     평일 폐점 토요일 일요일 연중무휴
# 0     ACUB휘트니스  06:00:00  00:00:00   Y   N    N
# 1  스포애니 강남역1호점  06:00:00  00:00:00   Y   N    N
# 2    스포애니 논현역점  06:00:00  00:00:00   Y   Y    N
# 3    스포애니 대치동점  07:00:00  23:00:00   Y   N    N
# 4    스포애니 선릉역점  08:00:00  23:00:00   Y   Y    N

# %%
hour['평일 폐점'].unique()
# Out:
# array([datetime.time(0, 0), datetime.time(23, 0), datetime.time(22, 0),
#        datetime.time(23, 50), datetime.time(20, 0), datetime.time(20, 30),
#        datetime.time(23, 20), datetime.time(23, 30), datetime.time(21, 0),
#        datetime.time(22, 30), datetime.time(18, 0), datetime.time(0, 30),
#        datetime.time(23, 59), datetime.time(21, 30), datetime.time(1, 0),
#        datetime.time(2, 0)], dtype=object)

# %% [markdown]
# #### 4.2 영업시간(막대그래프)

# %% [markdown]
# ##### [시행착오] 자정이후 시간 자정기준 우측 배열하기 (열람 불필요ㅠㅠ)

# %%
# 시간 범위 생성
time_range = list(range(1, 25))  # 1 ~ 24

# 시간 추출
business_hours = []
for _, row in hour.iterrows():
    business_hours.extend(list(range(row['평일 개점'].hour, row['평일 폐점'].hour + 1)))

# Seaborn 스타일 설정
sns.set(style="white")
# sns.set(style="white")

# 히스토그램 그리기
plt.figure(figsize=(6, 4))
sns.histplot(business_hours, bins=time_range, kde=True, color='skyblue')
plt.xlabel('영업 시간 (24시간)', fontproperties=fontprop)
plt.ylabel('사업장 수', fontproperties=fontprop)
plt.title('사업장별 평일 영업 시간 분포', fontproperties=fontprop_title)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# '평일 개점' 열과 '평일 폐점' 열이 다른 데이터 필터링
different_hours = hour[hour['평일 개점'] != hour['평일 폐점']]

# seaborn을 이용한 히스토그램 그리기
plt.figure(figsize=(10, 6))
sns.histplot(different_hours['평일 폐점'].apply(lambda x: x.hour), bins=24, color='skyblue', edgecolor='black', kde=False)

# xticks 설정
plt.xticks(range(24), range(24))  # 모든 정수 표시

# 12시 이후부터 새벽 2시까지의 값은 우측에 배열
plt.xticks(rotation=45, ha='right')
plt.xticks(range(24), [f"{i+24 if i<12 else i}" for i in range(24)])  # 12시부터 24시까지 24를 더한 값으로 표시

plt.title('평일 폐점 시간 히스토그램 (평일 개점과 폐점이 다른 경우)')
plt.xlabel('시간 (24시간 형식)')
plt.ylabel('빈도')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48712 (\N{HANGUL SYLLABLE BIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# '평일 개점' 열과 '평일 폐점' 열이 다른 데이터 필터링
different_hours = hour[hour['평일 개점'] != hour['평일 폐점']]

# seaborn을 이용한 히스토그램 그리기
plt.figure(figsize=(10, 6))
sns.histplot(different_hours['평일 폐점'].apply(lambda x: x.hour), bins=24, color='skyblue', edgecolor='black', kde=False)

# xticks 설정
plt.xticks(range(24), range(24))  # 모든 정수 표시

# 12시 이후부터 새벽 2시까지의 값은 우측에 배열
plt.xticks(rotation=45, ha='right')
plt.xticks(range(24), [f"{i+24 if i<4 else i}" for i in range(24)])  # 12시부터 24시까지 24를 더한 값으로 표시

plt.title('평일 폐점 시간 히스토그램 (평일 개점과 폐점이 다른 경우)')
plt.xlabel('시간 (24시간 형식)')
plt.ylabel('빈도')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48712 (\N{HANGUL SYLLABLE BIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# '평일 개점' 열과 '평일 폐점' 열이 다른 데이터 필터링
different_hours = hour[hour['평일 개점'] != hour['평일 폐점']]

# '평일 폐점' 열의 시간을 datetime 형태로 변환
# different_hours['평일 폐점'] = pd.to_datetime(different_hours['평일 폐점'])

# seaborn을 이용한 히스토그램 그리기
plt.figure(figsize=(10, 6))
sns.histplot(different_hours['평일 폐점'].apply(lambda x: (x.hour + 12) % 24), bins=24, color='skyblue', edgecolor='black', kde=False,)
# sns.histplot(different_hours['평일 폐점'].apply(lambda x: (x.hour + 12) % 24), bins=24, color='skyblue',  kde=False, stat='count', common_norm=False, element='step', fill=False, linewidth=2)
# xticks 설정
plt.xticks(range(24), [f"{i}" for i in range(12, 24)] + [f"{i}" for i in range(12)])  # 밤 12시 이후의 값은 그래프 왼쪽에 연속해서 표시

plt.title('평일 폐점 시간 분포',fontproperties=fontprop_title)
plt.xlabel('시간 (24시간 형식)', fontproperties=fontprop)
plt.ylabel('빈도', fontproperties=fontprop)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
from matplotlib.font_manager import FontProperties

# '평일 개점' 열과 '평일 폐점' 열이 다른 데이터 필터링
different_hours = hour[hour['평일 개점'] != hour['평일 폐점']]

# seaborn을 이용한 히스토그램 그리기
plt.figure(figsize=(10, 6))
sns.histplot(different_hours['평일 폐점'].apply(lambda x: (x.hour * 60 + x.minute + 30) % 1440), bins=48, color='skyblue', edgecolor='black', kde=False)

# xticks 설정
xticks = [i * 30 for i in range(0, 48) if i * 30 < 24 * 60]
xticklabels = [f"{i // 60:02d}:{i % 60:02d}" for i in xticks]
plt.xticks(xticks, xticklabels, rotation=45)

# 그래프 범위 설정 (오후 4시부터 새벽 4시까지)
plt.xlim(960, 1440)


plt.title('평일 폐점 시간 분포', fontproperties=fontprop_title)
plt.xlabel('시간 (24시간 형식)', fontproperties=fontprop)
plt.ylabel('빈도', fontproperties=fontprop)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# seaborn을 이용한 히스토그램 그리기
plt.figure(figsize=(10, 6))
# sns.histplot(different_hours['평일 폐점'].apply(lambda x: (x.hour * 60 + x.minute + 30) % 1440), bins=48, color='skyblue', edgecolor='black', kde=False)
# 24시간을 넘어가는 값 처리
values = different_hours['평일 폐점'].apply(lambda x: (x.hour * 60 + x.minute + 30) % 1440)
values[values < 180] += 1440  # 24시간을 더해줌
sns.histplot(values, bins=48, color='skyblue', edgecolor='black', kde=False)

# # xticks 설정
# xticks = [i * 30 for i in range(0, 48) if i * 30 < 24 * 60]
# xticklabels = [f"{i // 60:02d}:{i % 60:02d}" for i in xticks]
# plt.xticks(xticks, xticklabels, rotation=45)

# xticks 설정
xticks = [i * 30 for i in range(32, 48)]  # 32부터 47까지만 표시
xticklabels = [f"{i // 60:02d}:{i % 60:02d}" for i in xticks]
plt.xticks(xticks, xticklabels)

# xtickslabel이 없는 문제 해결
plt.xticks(rotation=45, ha='right', fontsize=8)

# 그래프 범위 설정 (오후 4시부터 자정까지)
plt.xlim(960, 1560)

plt.title('평일 폐점 시간 분포', fontproperties=fontprop_title)
plt.xlabel('시간 (24시간 형식)', fontproperties=fontprop)
plt.ylabel('빈도', fontproperties=fontprop)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
from matplotlib.font_manager import FontProperties

# 한글 폰트 설정
fontprop_title = FontProperties(fname=font_path, size=14)
fontprop = FontProperties(fname=font_path, size=12)

# '평일 개점' 열과 '평일 폐점' 열이 다른 데이터 필터링
different_hours = hour[hour['평일 개점'] != hour['평일 폐점']]

# seaborn을 이용한 히스토그램 그리기
plt.figure(figsize=(10, 6))
# 24시간을 넘어가는 값 처리
values = different_hours['평일 폐점'].apply(lambda x: (x.hour * 60 + x.minute + 30) % 1440)
values[values < 960] += 1440  # 24시간을 더해줌
sns.histplot(values, bins=48, color='skyblue', edgecolor='black', kde=False)

# xticks 설정
xticks = [i * 30 for i in range(34, 48)]  # 34부터 47까지만 표시 (5시 이후)
xticklabels = [f"{i // 60:02d}:{i % 60:02d}" for i in xticks]
plt.xticks(xticks, xticklabels)

# xtickslabel이 없는 문제 해결
plt.xticks(rotation=45, ha='right', fontsize=8)

# 그래프 범위
# Out:
# (array([1020, 1050, 1080, 1110, 1140, 1170, 1200, 1230, 1260, 1290, 1320,
#         1350, 1380, 1410]),
#  [Text(1020, 0, '17:00'),
#   Text(1050, 0, '17:30'),
#   Text(1080, 0, '18:00'),
#   Text(1110, 0, '18:30'),
#   Text(1140, 0, '19:00'),
#   Text(1170, 0, '19:30'),
#   Text(1200, 0, '20:00'),
#   Text(1230, 0, '20:30'),
#   Text(1260, 0, '21:00'),
#   Text(1290, 0, '21:30'),
#   Text(1320, 0, '22:00'),
#   Text(1350, 0, '22:30'),
#   Text(1380, 0, '23:00'),
#   Text(1410, 0, '23:30')])
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 54224 (\N{HANGUL SYLLABLE PYE}) missing from current font.
# ...

# %%
# seaborn을 이용한 히스토그램 그리기
plt.figure(figsize=(10, 6))

# 24시간을 넘어가는 값 처리
values = different_hours['평일 폐점'].apply(lambda x: (x.hour * 60 + x.minute + 30) % 1440)
values[values < 960] += 1440  # 24시간을 더해줌
sns.histplot(values, bins=48, color='skyblue', edgecolor='black', kde=False)

# xticks 설정
xticks = [i * 30 for i in range(0, 48) if i * 30 < 24 * 60]
xticklabels = [f"{i // 60:02d}:{i % 60:02d}" for i in xticks]
plt.xticks(xticks, xticklabels, rotation=45)

# 그래프 범위 설정 (오후 4시부터 자정까지)
plt.xlim(960, 2400)

plt.title('평일 폐점 시간 분포', fontproperties=fontprop_title)
plt.xlabel('시간 (24시간 형식)', fontproperties=fontprop)
plt.ylabel('빈도', fontproperties=fontprop)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
from matplotlib.font_manager import FontProperties

# 한글 폰트 설정
fontprop_title = FontProperties(fname=font_path, size=14)
fontprop = FontProperties(fname=font_path, size=12)

# '평일 개점' 열과 '평일 폐점' 열이 다른 데이터 필터링
different_hours = hour[hour['평일 개점'] != hour['평일 폐점']]

# seaborn을 이용한 히스토그램 그리기
plt.figure(figsize=(10, 6))
# 24시간을 넘어가는 값 처리
values = different_hours['평일 폐점'].apply(lambda x: (x.hour * 60 + x.minute + 30) % 1440)
values[values < 960] += 1440  # 24시간을 더해줌
sns.histplot(values, bins=48, color='skyblue', edgecolor='black', kde=False)

# xticks 설정
xticks = [i * 30 for i in range(34, 48)]  # 34부터 47까지만 표시 (5시 이후)
xticklabels = [f"{i // 60:02d}:{i % 60:02d}" for i in xticks]
plt.xticks(xticks, xticklabels)

# xtickslabel이 없는 문제 해결
plt.xticks(rotation=45, ha='right', fontsize=8)

# 그래프 범위 설정 (오후 5시부터 자정까지)
plt.xlim(1020, 1560)

# xticks 위치 설정 (30분 간격)
plt.gca().xaxis.set_major_locator(MultipleLocator(30))

plt.title('평일 폐점 시간 분포', fontproperties=fontprop_title)
plt.xlabel('시간 (24시간 형식)', fontproperties=fontprop)
plt.ylabel('빈도', fontproperties=fontprop)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# seaborn을 이용한 히스토그램 그리기
plt.figure(figsize=(10, 6))
# 24시간을 넘어가는 값 처리
values = different_hours['평일 폐점'].apply(lambda x: (x.hour * 60 + x.minute + 30) % 1440)
values[values < 960] += 1440  # 24시간을 더해줌
sns.histplot(values, bins=48, color='skyblue', edgecolor='black', kde=False)

# xticks 설정
xticks = [i * 30 for i in range(0, 48) if i * 30 < 24 * 60]
xticklabels = [f"{i // 60:02d}:{i % 60:02d}" for i in xticks]
plt.xticks(xticks, xticklabels)

# xtickslabel이 없는 문제 해결
plt.xticks(rotation=45, ha='right', fontsize=8)

# 그래프 범위 설정 (오후 4시부터 자정까지)
plt.xlim(960, 2400)

plt.title('평일 폐점 시간 분포', fontproperties=fontprop_title)
plt.xlabel('시간 (24시간 형식)', fontproperties=fontprop)
plt.ylabel('빈도', fontproperties=fontprop)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# '평일 개점' 열과 '평일 폐점' 열이 다른 데이터 필터링
different_hours = hour[hour['평일 개점'] != hour['평일 폐점']]

# '평일 폐점' 열의 시간을 datetime 형태로 변환
# different_hours['평일 폐점'] = pd.to_datetime(different_hours['평일 폐점'])

# seaborn을 이용한 히스토그램 그리기
plt.figure(figsize=(10, 6))
sns.histplot(different_hours['평일 폐점'].apply(lambda x: (x.hour + 12) % 24), bins=range(12, 36), color='skyblue', edgecolor='black', kde=False)

# xticks 설정
plt.xticks(range(12, 36), [f"{i % 24}" for i in range(12, 36)])  # 밤 12시 이후의 값은 그래프 왼쪽에 연속해서 표시

plt.title('평일 폐점 시간 히스토그램 (평일 개점과 폐점이 다른 경우)')
plt.xlabel('시간 (24시간 형식)')
plt.ylabel('빈도')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48712 (\N{HANGUL SYLLABLE BIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# seaborn을 이용한 히스토그램 그리기
plt.figure(figsize=(10, 6))
sns.histplot(hour['평일 폐점'].apply(lambda x: x.hour), bins=24, color='skyblue', edgecolor='black', kde=False)

# xticks 설정
plt.xticks(range(24), range(24))  # 모든 정수 표시

# 12시 이후부터 새벽 2시까지의 값은 우측에 배열
plt.xticks(rotation=45, ha='right')
plt.xticks(range(24), [f"{i+24 if i<12 else i}" for i in range(24)])  # 12시부터 24시까지 24를 더한 값으로 표시

plt.title('평일 폐점 시간 히스토그램')
plt.xlabel('시간 (24시간 형식)')
plt.ylabel('빈도')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48712 (\N{HANGUL SYLLABLE BIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# seaborn을 이용한 히스토그램 그리기
plt.figure(figsize=(10, 6))
sns.histplot(hour['평일 폐점'].apply(lambda x: x.hour), bins=24, color='skyblue', edgecolor='black', kde=False)

# xticks 설정
plt.xticks(range(24), [f"{i+24 if i<12 else i}" for i in range(24)])  # 12시부터 24시까지 24를 더한 값으로 표시

# 12시 이후부터 새벽 2시까지의 값은 우측에 배열
plt.xticks(rotation=45, ha='right')

plt.title('평일 폐점 시간 히스토그램')
plt.xlabel('시간 (24시간 형식)')
plt.ylabel('빈도')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48712 (\N{HANGUL SYLLABLE BIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# seaborn을 이용한 히스토그램 그리기
plt.figure(figsize=(10, 6))
sns.histplot(hour['평일 폐점'].apply(lambda x: (x.hour + 12) % 24), bins=24, color='skyblue', edgecolor='black', kde=False)

# xticks 설정
plt.xticks(range(24), [f"{i}" for i in range(12, 24)] + [f"{i}" for i in range(12)])  # 밤 12시 이후의 값은 그래프 오른쪽에 연속해서 표시

# 12시 이후부터 새벽 2시까지의 값은 우측에 배열
plt.xticks(rotation=45, ha='right')

plt.title('평일 폐점 시간 히스토그램')
plt.xlabel('시간 (24시간 형식)')
plt.ylabel('빈도')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48712 (\N{HANGUL SYLLABLE BIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# seaborn을 이용한 히스토그램 그리기
plt.figure(figsize=(10, 6))
sns.histplot(hour['평일 폐점'].apply(lambda x: (x.hour + 12) % 24), bins=24, color='skyblue', edgecolor='black', kde=False)

# xticks 설정
plt.xticks(range(24), [f"{i}" for i in range(12, 24)] + [f"{i}" for i in range(12)])  # 밤 12시 이후의 값은 그래프 오른쪽에 연속해서 표시

# 12시 이후부터 새벽 2시까지의 값은 우측에 배열
plt.xticks(rotation=45, ha='right')

plt.title('평일 폐점 시간 히스토그램')
plt.xlabel('시간 (24시간 형식)')
plt.ylabel('빈도')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48712 (\N{HANGUL SYLLABLE BIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 한글 폰트 설정
plt.rc('font', family='NanumGothic')
sns.set(font="NanumGothic")

# 시간 범위 생성
time_range = list(range(1, 25))

# 시간 추출
business_hours = []
for _, row in hour.iterrows():
    business_hours.extend(list(range(row['평일 개점'].hour, row['평일 폐점'].hour)))

# Seaborn 그리드제거
sns.set(style="white")

# 히스토그램 그리기
plt.figure(figsize=(6, 4))
sns.histplot(business_hours, bins=time_range, kde=False, color='darkgrey')

plt.xlabel('영업 시간 (24시간)', fontproperties=fontprop)
plt.ylabel('사업장 수', fontproperties=fontprop)
plt.title('사업장별 평일 영업 시간 분포', fontproperties=fontprop_title)
plt.xticks(range(0, 25))
plt.show()

# %% [markdown]
# ##### [성공!] 자정이후 시간 자정기준 우측 배열하기

# %%
# seaborn을 이용한 히스토그램 그리기
plt.figure(figsize=(8, 4))
sns.histplot(hour['평일 폐점'].apply(lambda x: (x.hour + 12) % 24), bins=24, color=palette2[7], edgecolor='grey', kde=False, binwidth=1)

# xticks 설정
plt.xticks(range(24), [f"{i}" for i in range(12, 24)] + [f"{i}" for i in range(12)])  # 밤 12시 이후의 값은 그래프 오른쪽에 연속해서 표시

# 12시 이후부터 새벽 2시까지의 값은 우측에 배열
plt.xticks(rotation=45, ha='center', va='center_baseline')

# 그래프 범위 설정 (오후 5시부터 새벽 3시까지)
plt.xlim(5, 15)  # 17(5시)부터 27(3시)까지의 범위

plt.title('폐점 시간 분포', fontproperties=fontprop_title, fontsize=32)
plt.xlabel('시간', fontproperties=fontprop)
plt.ylabel('사업장 수', fontproperties=fontprop)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #### 4.3 토,일,연휴 영업 (원그래프)

# %% [markdown]
# ##### 4.3.1 개별 원그래프(토,일,연중무휴)

# %%
plt.figure(figsize=(4, 4))
hour['토요일'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightcoral'])
plt.title('토요일 영업', fontproperties=fontprop_title)
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(4, 4))
hour['일요일'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightblue'])
plt.title('일요일 영업', fontproperties=fontprop_title)
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(4, 4))
hour['연중무휴'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightblue'])
plt.title('공휴일 및 연휴 영업', fontproperties=fontprop_title)
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 4.3.2 통합 원그래프(토,일,연중무휴)

# %%
hour['일요일'].unique
# Out:
# <bound method Series.unique of 0      N
# 1      N
# 2      Y
# 3      N
# 4      Y
#       ..
# 333    N
# 334    N
# 335    N
# 336    N
# 337    Y
# Name: 일요일, Length: 338, dtype: object>

# %%
# '일요일' 열에서 소문자 'y'를 대문자 'Y'로 변경
hour['일요일'] = hour['일요일'].apply(lambda x: 'Y' if x == 'y' else x)

# %%
# Set the Korean font
plt.rc('font', family='NanumGothic')

# Create a 1x3 subplot layout
plt.figure(figsize=(12, 4))

# Plot the first pie chart (토요일 영업)
plt.subplot(131)
hour['토요일'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors = [palette4[1], palette4[0]])
plt.title('토요일 영업', fontproperties=fontprop_title, fontsize=24)
plt.ylabel('')

# Plot the second pie chart (일요일 영업)
plt.subplot(132)
hour['일요일'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors = [palette4[0], palette4[1]])
plt.title('일요일 영업', fontproperties=fontprop_title, fontsize=24)
plt.ylabel('')

# Plot the third pie chart (공휴일 및 연휴 영업)
plt.subplot(133)
hour['연중무휴'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors = [palette4[0], palette4[1]])
plt.title('연중무휴', fontproperties=fontprop_title)
plt.ylabel('')

# Adjust layout spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Set the Korean font
plt.rc('font', family='NanumGothic')

# Create a 1x3 subplot layout
plt.figure(figsize=(12, 4))

# Plot the first pie chart (토요일 영업)
plt.subplot(131)
plt.pie(hour['토요일'].value_counts(), labels=hour['토요일'].value_counts().index, autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightcoral'], wedgeprops=dict(edgecolor='black'))
plt.title('토요일 영업', fontproperties=fontprop_title)
plt.ylabel('')

# Plot the second pie chart (일요일 영업)
plt.subplot(132)
plt.pie(hour['일요일'].value_counts(), labels=hour['일요일'].value_counts().index, autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightblue'], wedgeprops=dict(edgecolor='black'))
plt.title('일요일 영업', fontproperties=fontprop_title)
plt.ylabel('')

# Plot the third pie chart (공휴일 및 연휴 영업)
plt.subplot(133)
plt.pie(hour['연중무휴'].value_counts(), labels=hour['연중무휴'].value_counts().index, autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightblue'], wedgeprops=dict(edgecolor='black'))
plt.title('연중무휴', fontproperties=fontprop_title)
plt.ylabel('')

# Adjust layout spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Set the Korean font
plt.rc('font', family='NanumGothic')

# Create a 1x3 subplot layout
plt.figure(figsize=(12, 4))

# Plot the first pie chart (토요일 영업)
plt.subplot(131)
wedges, texts, autotexts = plt.pie(hour['토요일'].value_counts(), labels=['N', 'Y'], autopct='', startangle=90, colors=['lightblue', 'lightcoral'], wedgeprops=dict(edgecolor='black'))
plt.title('토요일 영업', fontproperties=fontprop_title)
plt.setp(autotexts, size=20, weight="bold")  # 값 폰트 크기 설정
plt.ylabel('')

# Add the 'Y' and 'N' labels inside the pie chart
for text, autotext in zip(texts, autotexts):
    text.set(size=15, weight="bold")
    autotext.set(size=15, weight="bold")
    x, y = autotext.get_position()
    plt.text(x, y, autotext.get_text(), ha='center', va='center', color='white')

# Plot the second pie chart (일요일 영업)
plt.subplot(132)
wedges, texts, autotexts = plt.pie(hour['일요일'].value_counts(), labels=['N', 'Y'], autopct='', startangle=90, colors=['lightcoral', 'lightblue'], wedgeprops=dict(edgecolor='black'))
plt.title('일요일 영업', fontproperties=fontprop_title)
plt.setp(autotexts, size=20, weight="bold")  # 값 폰트 크기 설정
plt.ylabel('')

# Add the 'Y' and 'N' labels inside the pie chart
for text, autotext in zip(texts, autotexts):
    text.set(size=15, weight="bold")
    autotext.set(size=15, weight="bold")
    x, y = autotext.get_position()
    plt.text(x, y, autotext.get_text(), ha='center', va='center', color='white')

# Plot the third pie chart (공휴일 및 연휴 영업)
plt.subplot(133)
wedges, texts, autotexts = plt.pie(hour['연중무휴'].value_counts(), labels=['N', 'Y'], autopct='', startangle=90, colors=['lightcoral', 'lightblue'], wedgeprops=dict(edgecolor='black'))
plt.title('연중무휴', fontproperties=fontprop_title)
plt.setp(autotexts, size=20, weight="bold")  # 값 폰트 크기 설정
plt.ylabel('')

# Add the 'Y' and 'N' labels inside the pie chart
for text, autotext in zip(texts, autotexts):
    text.set(size=15, weight="bold")
    autotext.set(size=15, weight="bold")
    x, y = autotext.get_position()
    plt.text(x, y, autotext.get_text(), ha='center', va='center', color='white')

# Adjust layout spacing
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### 5. 가격정보

# %% [markdown]
# #### 5.1 데이터보기

# %%
rate.head()
# Out:
#           사업장명    일일권    3개월권     1년권
# 0     ACUB휘트니스   9900  250000  450000
# 1  스포애니 강남역1호점  10000   90000  240000
# 2    스포애니 논현역점  10000   90000  240000
# 3    스포애니 대치동점  10000   90000  240000
# 4    스포애니 선릉역점  10000   90000  240000

# %% [markdown]
# #### 5.2 가격정보 히스토그램 (일일권, 3개월권, 1년권)

# %%
# # 나눔고딕 폰트 설정
# plt.rc('font', family='NanumGothic')
# sns.set(font="NanumGothic")

# 숫자형으로 변환하고 변환에 실패하는 경우 NaN으로 대체 후 NaN이 포함된 행 제거
rate['일일권'] = pd.to_numeric(rate['일일권'], errors='coerce')
rate['3개월권'] = pd.to_numeric(rate['3개월권'], errors='coerce')
rate['1년권'] = pd.to_numeric(rate['1년권'], errors='coerce')
rate.dropna(inplace=True)


# Seaborn 스타일 설정
sns.set(style="white")

# 열 이름에 따라 히스토그램 그리기
plt.figure(figsize=(12, 4))

for i, col in enumerate(['일일권', '3개월권', '1년권']):
    plt.subplot(1, 3, i + 1)
    sns.histplot(rate, x=col, kde=False, color=palette4[i], bins=5, edgecolor='gray')
    plt.title(f'{col} 가격', fontproperties=fontprop_title)
    plt.xlabel('가격', fontproperties=fontprop)
    plt.ylabel('사업장 수', fontproperties=fontprop)


 # xticks 각 막대의 중심에 맞게 설정
    bin_centers = (0.5 * (plt.hist(rate[col], bins=5, alpha=0)[1][1:] + plt.hist(rate[col], bins=5, alpha=0)[1][:-1]))

    if i == 0:
        plt.ylabel('사업장 수', fontproperties=fontprop)
        plt.xticks(bin_centers, ['1만', '2만', '3만', '4만', '5만 이상'],  fontproperties=fontprop)  # rotation=45,
    elif i == 1:
        plt.ylabel('')  # ylabel 없애기
        plt.xticks(bin_centers, ['10만', '20만', '30만', '40만', '50만 이상'],  fontproperties=fontprop)  # rotation=45,
    else:
        plt.ylabel('')  # ylabel 없애기
        plt.xticks(bin_centers, ['40만', '80만', '120만', '160만', '200만 이상'], ha='center', fontproperties=fontprop)  # rotation=45,

plt.tight_layout()
plt.show()
